# %% [markdown]
# # <u>**CASE STUDY1</u> - HEALTHCARE PROVIDER FRAUD DETECTION ANALYSIS**
#
# ![picture](https://drive.google.com/uc?id=1pLkGbp71slHrg7xgfVG4_T3r0-AbJhJP)
#
# This notebook contains:-
# 1. Model Training using Class Weight = 'Balanced' or Synthetic Minority OverSampling Technique to handle imbalanced data.
# 2. Conclusions drawn after Model Training.
#
# <u>Note</u>:
#
# Source of dataset: [Kaggle](https://www.kaggle.com/datasets/rohitrox/healthcare-provider-fraud-detection-analysis)
#
# Business aspect of features: [Features](https://docs.google.com/spreadsheets/d/1yaYsMDEV96UvKvwfsYLk3VnSf7u1po9MQFE_j3Y9kkI/edit?usp=share_link)
#
#
# ## <b>Notebook Content</b>

# %% [markdown]
# >[CASE STUDY1 - HEALTHCARE PROVIDER FRAUD DETECTION ANALYSIS](#scrollTo=elGnmCWLDc8G)
#
# >>[Notebook Content](#scrollTo=elGnmCWLDc8G)
#
# >>[Loading Packages/Libraries](#scrollTo=OdpdMrp0D0so)
#
# >>[Loading Data](#scrollTo=moB3N45qEQ65)
#
# >>>[2.1 Splitting data into X and Y](#scrollTo=sFjpLB2kEweO)
#
# >>>[2.2 Splitting and scaling data into Train and Cross Validation(or Test)](#scrollTo=6Nj2fYepEdKm)
#
# >>>>[2.2.1 Stratified Sampling(70:30)](#scrollTo=vY-Cd4f47Lri)
#
# >>>[2.3 Perform Dimensionality Reduction Techniques](#scrollTo=4oMcAJ5ijxT1)
#
# >>>>[2.3.1 Plot TSNE for Train Data (285 dimensions reduced to 2 dimension)](#scrollTo=lBs2Drme7tXh)
#
# >>>>[2.3.2 Perform PCA for Feature Reduction](#scrollTo=cHxbFPG97ztb)
#
# >>>>[2.3.3 Replace Train and CV(Test) Data with the best features](#scrollTo=lMIovuf-8O_s)
#
# >>>>[2.3.4 Store the Train and CV(Test) Data as csv for future use](#scrollTo=2fg2rXZK8l--)
#
# >>[Modelling with Class Weight = 'Balanced'](#scrollTo=HIMPlCwFyExg)
#
# >>>[3.1 Logistic Regression with hyperparameter tuning using Random Search CV](#scrollTo=6q9uFxEKkKq9)
#
# >>>>[3.1.1 Fitting logistic regression with best hyperparameters](#scrollTo=r-0snTag9g9V)
#
# >>>>[3.1.2 Finding the most important features using logistic regression with best hyperparameters](#scrollTo=wo4186fY96is)
#
# >>>>[3.1.3 Finding the least important features using logistic regression with best hyperparameters](#scrollTo=B7IHea7_c5mZ)
#
# >>>>[3.1.4 Summary of results](#scrollTo=UShywMygAGJ6)
#
# >>>[3.2 Decision Trees with hyperparameter tuning using Random Search CV](#scrollTo=oJdNmxRUkicd)
#
# >>>>[3.2.1 Fitting decision trees with best hyperparameters](#scrollTo=LlnfsQIl_zOk)
#
# >>>>[3.2.2 Finding the most important features using decision trees with best hyperparameters](#scrollTo=GzV1LRDRA99u)
#
# >>>>[3.2.3 Finding the least important features using decision trees with best hyperparameters](#scrollTo=nY6ujswqddD0)
#
# >>>>[3.2.4 Summary of results and its comparison with other models](#scrollTo=WbSpeXjlBT9J)
#
# >>>[3.3 XGB Classifier with hyperparameter tuning using Random Search CV](#scrollTo=ncm_B1icCN-k)
#
# >>>>[3.3.1 Fitting XGB Classifier with best hyperparameters](#scrollTo=sRMs6QC4CZOB)
#
# >>>>[3.3.2 Finding the most important features using XGB Classifier with best hyperparameters](#scrollTo=KVflMzYQCtJM)
#
# >>>>[3.3.3 Finding the least important features using XGB Classifier with best hyperparameters](#scrollTo=9JJ8fz2UC0HM)
#
# >>>>[3.3.4 Summary of results and its comparison with other models](#scrollTo=pu6DXT-IDCI9)
#
# >>[Loading Data](#scrollTo=TuMOu6NglnX7)
#
# >>>[4.1 Splitting and scaling data into Train and Cross Validation(or Test)](#scrollTo=TuMOu6NglnX7)
#
# >>>>[4.1.1 Stratified Sampling(80:20)](#scrollTo=TuMOu6NglnX7)
#
# >>>[4.2 Perform Dimensionality Reduction Techniques](#scrollTo=K6BS7RbgF1Gs)
#
# >>>>[4.2.1 Plot TSNE for Train Data (285 dimensions reduced to 2 dimension)](#scrollTo=K6BS7RbgF1Gs)
#
# >>>>[4.2.2 Perform PCA for Feature Reduction](#scrollTo=9Lk82mxtGDjh)
#
# >>>>[4.2.3 Replace Train and CV(Test) Data with the best features](#scrollTo=b1CZXWHcGGx6)
#
# >>>>[4.2.4 Store the Train and CV(Test) Data as csv for future use](#scrollTo=N6eM9mg_GO2K)
#
# >>[Modelling with Class Weight = 'Balanced'](#scrollTo=0m2gG2mlGpjQ)
#
# >>>[5.1 Fitting logistic regression with best hyperparameters](#scrollTo=uHereSG1IYM1)
#
# >>>>[5.1.1 Finding the most important features using logistic regression with best hyperparameters](#scrollTo=WTwRaxkJI7te)
#
# >>>>[5.1.2 Finding the least important features using logistic regression with best hyperparameters](#scrollTo=M3SRW4F1fYMf)
#
# >>>>[5.1.3 Summary of results and its comparison with other models](#scrollTo=A0oLrgaQJHq-)
#
# >>>[5.2 Fitting decision trees with best hyperparameters](#scrollTo=4-zsNIIdJZEO)
#
# >>>>[5.2.1 Finding the most important features using decision trees with best hyperparameters](#scrollTo=xJbLZcw6JdMD)
#
# >>>>[5.2.2 Finding the least important features using decision trees with best hyperparameters](#scrollTo=9BDBe7lcgaQL)
#
# >>>>[5.2.3 Summary of results and its comparison with other models](#scrollTo=ekWXb6vrJoe-)
#
# >>>[5.3 Fitting XGB Classifier with best hyperparameters](#scrollTo=IDKk5gDBJwK9)
#
# >>>>[5.3.1 Finding the most important features using XGB Classifier with best hyperparameters](#scrollTo=NKT4F84eJ6zb)
#
# >>>>[5.3.2 Finding the least important features using XGB Classifier with best hyperparameters](#scrollTo=WFGuILbyJ-Ha)
#
# >>>>[5.3.3 Summary of results and its comparison with other models](#scrollTo=ngmZX1rvKBne)
#
# >>[Loading Data](#scrollTo=liiQq3lHFtRO)
#
# >>>[6.1 Splitting and scaling data into Train and Cross Validation(or Test)](#scrollTo=liiQq3lHFtRO)
#
# >>>>[6.1.1 Stratified Sampling(70:30)](#scrollTo=liiQq3lHFtRO)
#
# >>>[6.2 SMOTE Sampling(70:30) for Imbalanced Data](#scrollTo=Z5LIJWqULsrL)
#
# >>>[6.3 Perform Dimensionality Reduction Techniques](#scrollTo=vjC7fZ8KLpp5)
#
# >>>>[6.3.1 Plot TSNE for Train Data (285 dimensions reduced to 2 dimension)](#scrollTo=vjC7fZ8KLpp5)
#
# >>>>[6.3.2 Perform PCA for Feature Reduction](#scrollTo=ww8crbZcMFcF)
#
# >>>>[6.3.3 Replace Train and CV(Test) Data with the best features](#scrollTo=Aw_R_L16MIYk)
#
# >>>>[6.3.4 Store the Train and CV(Test) Data as csv for future use](#scrollTo=6IBLc81iMLtG)
#
# >>[Modelling with Synthetic Minority Oversampling](#scrollTo=QJY0ChlrIH-b)
#
# >>>[7.1 Fitting logistic regression with best hyperparameters](#scrollTo=QJY0ChlrIH-b)
#
# >>>>[7.1.1 Finding the most important features using logistic regression with best hyperparameters](#scrollTo=aNs4iHpkQFIv)
#
# >>>>[7.1.2 Finding the least important features using logistic regression with best hyperparameters](#scrollTo=WG0HJ2mPh-Y2)
#
# >>>>[7.1.3 Summary of results and its comparison with other models](#scrollTo=LJZmX1MeQZml)
#
# >>>[7.2 Fitting decision trees with best hyperparameters](#scrollTo=qpl5a0BhQcfV)
#
# >>>>[7.2.1 Finding the most important features using decision trees with best hyperparameters](#scrollTo=lAhnzNTaQyr0)
#
# >>>>[7.2.2 Finding the least important features using decision trees with best hyperparameters](#scrollTo=GsHV2MnuiQ4L)
#
# >>>>[7.2.3 Summary of results and its comparison with other models](#scrollTo=T2ABxWHVQmuT)
#
# >>>[7.3 Fitting XGB Classifier with best hyperparameters](#scrollTo=LjDOgJ5fRMCg)
#
# >>>>[7.3.1 Finding the most important features using XGB Classifier with best hyperparameters](#scrollTo=2QXJtV-TXRG2)
#
# >>>>[7.3.2 Finding the least important features using XGB Classifier with best hyperparameters](#scrollTo=-nQvGHD2XWE7)
#
# >>>>[7.3.3 Summary of results and its comparison with other models](#scrollTo=jgiwBWDxXZdA)
#
# >>[Loading Data](#scrollTo=mUPf7YX6KjD6)
#
# >>>[8.1 Splitting and scaling data into Train and Cross Validation(or Test)](#scrollTo=mUPf7YX6KjD6)
#
# >>>>[8.1.1 Stratified Sampling(80:20)](#scrollTo=mUPf7YX6KjD6)
#
# >>>[8.2 SMOTE Sampling(80:20) for Imbalanced Data](#scrollTo=hoPpdDhMYUK0)
#
# >>>[8.3 Perform Dimensionality Reduction Techniques](#scrollTo=WfFX_4qyYXE8)
#
# >>>>[8.3.1 Plot TSNE for Train Data (285 dimensions reduced to 2 dimension)](#scrollTo=WfFX_4qyYXE8)
#
# >>>>[8.3.2 Perform PCA for Feature Reduction](#scrollTo=Kz2wKryHYayI)
#
# >>>>[8.3.3 Replace Train and CV(Test) Data with the best features](#scrollTo=xPRgn-7aYeDk)
#
# >>>>[8.3.4 Store the Train and CV(Test) Data as csv for future use](#scrollTo=yoFie5MgYiAy)
#
# >>[Modelling with Synthetic Minority Oversampling](#scrollTo=VL6v59eLKtPZ)
#
# >>>[9.1 Fitting logistic regression with best hyperparameters](#scrollTo=VL6v59eLKtPZ)
#
# >>>>[9.1.1 Finding the most important features using logistic regression with best hyperparameters](#scrollTo=FxwRmfNPcrfu)
#
# >>>>[9.1.2 Finding the least important features using logistic regression with best hyperparameters](#scrollTo=L5DvBcRdjRTt)
#
# >>>>[9.1.3 Summary of results and its comparison with other models](#scrollTo=T_AUUes0cutP)
#
# >>>[9.2 Fitting decision trees with best hyperparameters](#scrollTo=jOSxHJcYcyii)
#
# >>>>[9.2.1 Finding the most important features using decision trees with best hyperparameters](#scrollTo=kO3skN1mc2dZ)
#
# >>>>[9.2.2 Finding the least important features using decision trees with best hyperparameters](#scrollTo=frG2SYJ0kCOr)
#
# >>>>[9.2.3 Summary of results and its comparison with other models](#scrollTo=9afExyHSc6Gw)
#
# >>>[9.3 Fitting XGB Classifier with best hyperparameters](#scrollTo=oPFNvRudc99h)
#
# >>>>[9.3.1 Finding the most important features using XGB Classifier with best hyperparameters](#scrollTo=aIzfVs1cdBJZ)
#
# >>>>[9.3.2 Finding the least important features using XGB Classifier with best hyperparameters](#scrollTo=XSAO8PJzdFDM)
#
# >>>>[9.3.3 Summary of results and its comparison with other models](#scrollTo=BDGz9ycLdH6T)
#
# >>[Conclusion from Model Training](#scrollTo=rRJkYmaicO_4)

# %% [markdown]
# ## 1. Loading Packages/Libraries

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

import seaborn as sns
import matplotlib.pyplot as plt 

import math
import pandas as pd
import numpy as np
from tqdm import tqdm

from sklearn import metrics
from sklearn.metrics import roc_curve, auc, roc_auc_score, confusion_matrix, f1_score
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

from sklearn.decomposition import PCA
from collections import Counter
from sklearn.manifold import TSNE
from sklearn.utils.extmath import randomized_svd
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RandomizedSearchCV

from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier

from prettytable import PrettyTable
from sklearn.model_selection import StratifiedKFold
from imblearn.over_sampling import SMOTE

# %% [markdown]
# ## 2. Loading Data

# %%
# Code Reference: https://stackoverflow.com/questions/42320834/sklearn-changing-string-class-label-to-int

train_final = pd.read_csv('Final_Train.csv')                                    # loading csv
train_final['PotentialFraud'] = pd.factorize(train_final['PotentialFraud'])[0]  # replacing potential fraud = yes with 1 and no with 0
train_final.head()
# Out:
#    Provider  PotentialFraud  InscClaimAmtReimbursed  DeductibleAmtPaid  \
# 0  PRV51001               0                  104640             5340.0
# 1  PRV51003               1                  605670            66286.0
# 2  PRV51004               0                   52170              310.0
# 3  PRV51005               1                  280910             3700.0
# 4  PRV51007               0                   33710             3264.0
#
#    IsHospitalized  RenalDiseaseIndicator  NoOfMonths_PartACov  \
# 0               5                      8                  300
# 1              62                     29                 1560
# 2               0                     23                 1768
# 3               0                    259                13872
# 4               3                     11                  852
#
#    NoOfMonths_PartBCov  ChronicCond_Alzheimer  ChronicCond_Heartfailure  ...  \
# 0                  300                     15                        19  ...
# 1                 1567                     56                        80  ...
# 2                 1782                     64                        88  ...
# 3                13910                    426                       680  ...
# 4                  852                     26                        40  ...
#
#    count_ClaimID_perProviderClmDiagnosisCode_8  \
# 0                                          531
# 1                                         6792
# 2                                        19891
# 3                                      1258935
# 4                                         4362
#
#    count_ClaimID_perProviderClmDiagnosisCode_9  \
# 0                                          577
# 1                                         7632
# 2                                        21029
# 3                                      1297349
# 4                                         4494
#
#    count_ClaimID_perProviderClmDiagnosisCode_10  \
# 0                                           625
# 1                                         16134
# 2                                         22201
# 3                                       1354897
# 4                                          5042
#
#    count_ClaimID_perProviderDiagnosisGroupCode  Gender_0  Gender_1  Race_1  \
# 0                                          405      16.0       9.0    21.0
# 1                                         4972      78.0      54.0   107.0
# 2                                        22201     103.0      46.0   120.0
# 3                                      1357225     654.0     511.0   893.0
# 4                                         4764      38.0      34.0    58.0
#
#    Race_2  Race_3  Race_5
# 0     4.0     0.0     0.0
# 1    24.0     0.0     1.0
# 2    24.0     5.0     0.0
# 3   262.0    10.0     0.0
# 4    14.0     0.0     0.0
#
# [5 rows x 287 columns]

# %% [markdown]
# ### 2.1 Splitting data into X and Y

# %%
X = train_final.drop(axis=1, columns=['Provider','PotentialFraud'])             # drop potential fraud and provider columns from X
y = train_final['PotentialFraud']                                               # use potential fraud column as Y

print('Original Data Shape', X.shape, '\nClass Labels Shape', y.shape)
# Out:
# Original Data Shape (5410, 285)
# Class Labels Shape (5410,)

# %% [markdown]
# ### 2.2 Splitting and scaling data into Train and Cross Validation(or Test)

# %%
def train_cv_split_scaling(X, y, ratios):
  '''Function to split data into train and cross validation as per the passed ratio and perform standard scaling on it'''
  X_train, X_cv, y_train, y_cv = train_test_split(X, y, test_size=ratios , stratify=y, random_state=49)   # train test split
  print('X_train Shape = ', X_train.shape, '\nX_cv Shape = ', X_cv.shape, '\nY_train Shape = ',  y_train.shape, '\nY_cv Shape = ', y_cv.shape)
  
  standard_scaler = StandardScaler()
  standard_scaler.fit(X_train)
  X_train_std = standard_scaler.transform(X_train)                                                        # stadardize train data
  X_cv_std = standard_scaler.transform(X_cv)                                                              # stadardize cv data

  X_train_df = pd.DataFrame(X_train_std, columns=X.columns)                                               # store train data as dataframe
  X_cv_df = pd.DataFrame(X_cv_std, columns=X.columns)                                                     # store cv data as dataframe

  return X_train_std, X_cv_std, y_train, y_cv, X_train_df, X_cv_df                                        # return train/cv data and dataframes

def fraud_per(y_tr):
  '''Function to calculate fraud/non-fraud percentage with y train'''
  count = Counter(y_tr)
  fraud_percent = (count[1]*100/(count[0]+count[1]))                                                      # count 1's and calculate fraud percentages
  non_fraud_percent = (count[0]*100/(count[0]+count[1]))                                                  # count 0's and calculate non-fraud percentages
  print("Fraud Percentage = {:.2f}% \nNon-Fraud Percentage = {:.2f}%".format(fraud_percent, non_fraud_percent))

# %% [markdown]
# #### 2.2.1 Stratified Sampling(70:30)

# %%
X_train_std, X_cv_std, y_train, y_cv, X_train_df, X_cv_df = train_cv_split_scaling(X, y, 0.30)            # function call
fraud_per(y_train)                                                                                        # function call
# Out:
# X_train Shape =  (3787, 285)
# X_cv Shape =  (1623, 285)
# Y_train Shape =  (3787,)
# Y_cv Shape =  (1623,)
# Fraud Percentage = 9.35%
# Non-Fraud Percentage = 90.65%

# %% [markdown]
# ### 2.3 Perform Dimensionality Reduction Techniques

# %%
# Code Reference: https://www.geeksforgeeks.org/ml-t-distributed-stochastic-neighbor-embedding-t-sne-algorithm/

def plot_TSNE(x_tr, y_tr):
  '''Function to plot a dataset with 285 features after reducing it to 2 dimensions using TSNE'''
  data_1000 = x_tr[0:1000, :]
  labels_1000 = y_tr[0:1000]
  model = TSNE(n_components = 2, random_state = 0)

  tsne_data = model.fit_transform(data_1000)
  tsne_data = np.vstack((tsne_data.T, labels_1000)).T
  tsne_df = pd.DataFrame(data = tsne_data, columns =("Dimension_0", "Dimension_1", "label"))      # store 2-D TSNE data into dataframe

  with plt.style.context('seaborn-white'):                                                        # Set the white background for graph plotting 
    plt.figure(figsize=(8,5))
    sns.FacetGrid(tsne_df, hue ="label", size = 6).map(plt.scatter, 'Dimension_0', 'Dimension_1')
    plt.title('Dimensionality Reduction to 2 Features using TSNE')                                # Add title of the plot
    plt.grid(linestyle = '-')                                                                     # Add grid to the plot
    plt.legend(loc="upper left", title="Potential Fraud")                                         # Add legend to the plot

  plt.show()

# Code Reference: https://machinelearningmastery.com/principal-components-analysis-for-dimensionality-reduction-in-python/

def feat_reduct_PCA(x_tr, x_cv, y_cv):
  '''Function that uses PCA for feature reduction and plots features versus the best auroc score for selected features after applying LR model'''
  comp = [i for i in range(30,290,10)]
  score_list = []

  for i in comp:
    pca = PCA(n_components = i, svd_solver ='randomized')
    U, S, VT = randomized_svd(x_tr, n_components = i)
    pca.fit(x_tr)                                                                                # Fit train data to PCA
    data_cv_pca = pca.transform(x_cv)                                                            # Transform CV Data
    model = LogisticRegression(random_state=49)                                                  # Apply Logistic Regression for getting best AUROC score
    scores = cross_val_score(model, data_cv_pca, y_cv, scoring='roc_auc', cv=5)
    score_list.append(np.mean(scores))                                                           # Store AUROC scores in a list
  print('AUROC scores for different values of features:\n', score_list)

  plt.figure(figsize=(8,5))
  plt.plot(comp, score_list, 'bx-')
  plt.xlabel('Number of Features')                                                               # Add label to x-axis
  plt.ylabel('AUROC on CV Data')                                                                 # Add label to y-axis
  plt.title('Feature Reduction using PCA')                                                       # Add title of the plot
  plt.grid(linestyle = '-')                                                                      # Add grid to the plot
  plt.show()

# Code Reference: https://stackoverflow.com/questions/50796024/feature-variable-importance-after-a-pca-analysis

def feat_after_reduction(n, x_tr, x, x_tr_csv, x_cv_csv):
  '''Function which takes n features with best auroc score and returns the names of it using dataframe'''
  np.random.seed(0)
  pca = PCA(n_components = n, svd_solver ='randomized').fit(x_tr)
  print("Explained Variance using PCA with randomized svd_solver:\n", pca.explained_variance_ratio_)
  data_pca = pca.transform(x_tr)
  n_pcs= pca.components_.shape[0]
  
  most_important = [290]
  for i in tqdm(range(n_pcs)):
    idx = np.argpartition(pca.components_[i], -10)[-10:]                                        # find index with max variance ratio in ith row(top10)
    idx = list(idx[np.argsort(pca.components_[i][idx])])                                        # sort indices in ascending order of variance ratio
    idx.reverse()                                                                               # reverse the list
    for i in idx:
      if i not in most_important:                                                               # if index is already present in list take the next one
        most_important.append(i)
        break

  most_important = most_important[1:]
  initial_feature_names = list(x.columns)
  most_important_names = [initial_feature_names[most_important[i]] for i in range(n_pcs)]       # find the column names with respect to indices
  dic = {'PC{}'.format(i+1): most_important_names[i] for i in range(n_pcs)}
  df = pd.DataFrame(sorted(dic.items()))
  imp_feat= list(set(df[1]))
  print('\nUnique Feature Names with best Explained Variance Ratio:\n', imp_feat)
  x_tr = np.array(x_tr_csv[imp_feat])
  x_cv = np.array(x_cv_csv[imp_feat])
  print('Final X_train Shape = ', x_tr.shape, '\nFinal X_cv Shape = ', x_cv.shape)

  return imp_feat, x_tr, x_cv                                                                   # return column names for train and cv

# %% [markdown]
# #### 2.3.1 Plot TSNE for Train Data (285 dimensions reduced to 2 dimension)

# %%
plot_TSNE(X_train_std, y_train)                                       # function call

# %% [markdown]
# #### 2.3.2 Perform PCA for Feature Reduction

# %%
feat_reduct_PCA(X_train_std, X_cv_std, y_cv)                       # function call
# Out:
# AUROC scores for different values of features:
#  [0.9345353184831431, 0.9388617275960869, 0.9391585528689331, 0.9381452288588115, 0.9360524009129806, 0.9359668182928356, 0.9366300358670896, 0.9366313450840515, 0.9366547522963987, 0.9364296116113658, 0.9365421819538824, 0.9363623158758674, 0.9364310745621376, 0.9364069358744045, 0.9364764260360605, 0.9364516327398466, 0.9364070127413093, 0.9364969073468645, 0.9364530188237131, 0.9364302662198467, 0.9364302662198469, 0.9364530188237131, 0.9364056266574426, 0.9363607760581907, 0.9363623158758674, 0.9364529419568083]

# %% [markdown]
# #### 2.3.3 Replace Train and CV(Test) Data with the best features

# %%
imp_feat, X_train_std, X_cv_std = feat_after_reduction(50, X_train_std, X, X_train_df, X_cv_df)       # function call
# Out:
# Explained Variance using PCA with randomized svd_solver:
#  [8.82397775e-01 7.92494714e-02 2.82495393e-02 3.37241801e-03
#  1.43090328e-03 7.97860813e-04 7.66142435e-04 4.87417064e-04
#  4.34161570e-04 3.19817772e-04 2.98542825e-04 2.52433423e-04
#  1.74544207e-04 1.51863164e-04 1.42711485e-04 1.24305398e-04
#  1.14823110e-04 9.95829469e-05 8.66522669e-05 7.39497084e-05
#  6.93417884e-05 6.20350118e-05 5.61802553e-05 4.99551089e-05
#  4.21614102e-05 4.09007896e-05 3.94154187e-05 3.62059036e-05
#  3.29159179e-05 3.09993645e-05 3.06458821e-05 2.83547479e-05
#  2.76761477e-05 2.57963875e-05 2.45305679e-05 2.29993227e-05
#  2.18204208e-05 2.09124941e-05 1.83547601e-05 1.66778252e-05
#  1.63852074e-05 1.42865398e-05 1.33800820e-05 1.20143115e-05
#  1.16953887e-05 1.06139924e-05 9.22270722e-06 8.91015767e-06
#  8.29286778e-06 7.81962533e-06]
# 100%|██████████| 50/50 [00:00<00:00, 46926.65it/s]
# Unique Feature Names with best Explained Variance Ratio:
#  ['mean_IPAnnualReimbursementAmt_perClmDiagnosisCode_7', 'mean_Claim_Days_perBeneID', 'mean_Claim_Days_perOtherPhysician', 'mean_Hospital_Days_perClmDiagnosisCode_5', 'Gender_1', 'mean_InscClaimAmtReimbursed_perOperatingPhysician', 'Race_3', 'mean_DeductibleAmtPaid_perBeneID', 'mean_DeductibleAmtPaid_perClmDiagnosisCode_9', 'mean_Hospital_Days_perOtherPhysician', 'ChronicCond_ObstrPulmonary', 'mean_Hospital_Days_perClmDiagnosisCode_2', 'mean_Hospital_Days_perAttendingPhysician', 'ChronicCond_KidneyDisease', 'mean_Hospital_Days_perClmDiagnosisCode_10', 'mean_Claim_Days_perProvider', 'ChronicCond_Alzheimer', 'mean_DeductibleAmtPaid_perAttendingPhysician', 'mean_Hospital_Days_perClmDiagnosisCode_9', 'RenalDiseaseIndicator', 'ChronicCond_stroke', 'count_ClaimID_perProviderDiagnosisGroupCode', 'mean_IPAnnualDeductibleAmt_perOtherPhysician', 'Race_5', 'mean_InscClaimAmtReimbursed_perClmDiagnosisCode_6', 'mean_DeductibleAmtPaid_perOperatingPhysician', 'Difference', 'mean_InscClaimAmtReimbursed_perOtherPhysician', 'count_ClaimID_perProviderAttendingPhysician', 'count_ClaimID_perProviderClmDiagnosisCode_4', 'count_ClaimID_perProviderBeneID', 'mean_Hospital_Days_perBeneID', 'mean_Hospital_Days_perOperatingPhysician', 'mean_InscClaimAmtReimbursed_perBeneID', 'mean_DeductibleAmtPaid_perOtherPhysician', 'ChronicCond_Depression', 'mean_IPAnnualReimbursementAmt_perBeneID', 'Race_2', 'mean_Hospital_Days_perClmDiagnosisCode_8', 'mean_Claim_Days_perClmDiagnosisCode_1', 'count_ClaimID_perProviderOtherPhysician', 'ChronicCond_Cancer', 'mean_Hospital_Days_perClmDiagnosisCode_1', 'mean_Hospital_Days_perClmDiagnosisCode_3', 'mean_Hospital_Days_perClmDiagnosisCode_4', 'mean_Hospital_Days_perClmDiagnosisCode_6', 'mean_IPAnnualDeductibleAmt_perOperatingPhysician', 'ChronicCond_Osteoporasis', 'mean_InscClaimAmtReimbursed_perClmDiagnosisCode_4', 'mean_Hospital_Days_perClmProcedureCode_1']
# Final X_train Shape =  (3787, 50)
# Final X_cv Shape =  (1623, 50)

# %% [markdown]
# #### 2.3.4 Store the Train and CV(Test) Data as csv for future use

# %%
X_train_std_df = pd.DataFrame(X_train_std, columns=imp_feat)                   # store Final X_train as dataframe 
X_cv_std_df = pd.DataFrame(X_cv_std, columns=imp_feat)                         # store Final X_cv as dataframe 
x_pf = pd.DataFrame(y_train, columns = ['PotentialFraud'])
X_train_std_df['PotentialFraud'] = list(x_pf['PotentialFraud'])                # store y_train in Final X_train dataframe
x_pf = pd.DataFrame(y_cv, columns = ['PotentialFraud'])
X_cv_std_df['PotentialFraud'] = list(x_pf['PotentialFraud'])                   # store y_cv in Final X_cv dataframe

X_train_std_df.to_csv('Final_train1.csv', index = False)                       # store important features as csv for X_train
X_cv_std_df.to_csv('Final_cv1.csv', index = False)                             # store important features as csv for X_cv

# %% [markdown]
# ## 3. Modelling with Class Weight = 'Balanced'

# %%
def pred_proba(clf, data):
  '''Function takes classifier and train/cv data and returns the predicted probability'''
  y_pred = clf.predict_proba(data)[:,1]                                               # predict probability of Class 1

  return y_pred

def find_best_threshold(threshould, fpr, tpr):
    '''Calculates threshold with max value of exp: tpr(1-fpr)'''
    t = threshould[np.argmax(tpr*(1-fpr))]                                            # (tpr*(1-fpr)) = maximum if fpr = very low and tpr = very high

    return t

def predict_with_best_t(proba, threshould):
    '''Calculates predicted probability for best threshold'''
    predictions = []
    for i in proba:
        if i>=threshould:                                                             # predict 1 if above threshold
            predictions.append(1)                                                     # store value in list
        else:                                                                         # predict 0 if below threshold
            predictions.append(0)                                                     # store value in list
    return predictions

def plot_confusion_matrix(best_t, x_tr, x_cv, y_tr, y_cv, y_tr_pred, y_cv_pred):
    '''Function takes best threshold, train/cv data and predicted train/cv data and returns train/cv predictions along with the confusion matrix'''
    fig, ax = plt.subplots(1,2, figsize=(10,4))
    cm = confusion_matrix(y_tr, predict_with_best_t(y_tr_pred, best_t))               # Calculate count of the confusion matrix for Train Data
    with plt.style.context('seaborn'):                                                # Set the background for graph plotting 
      sns.heatmap(cm, annot=True, fmt='d', ax=ax[0], cmap='YlGnBu')                   # Plot Heatmap of Train Confusion Matrix
      ax[0].set_title('Train Confusion Matrix')                                       # Add title of the plot
      ax[0].set_xlabel('Predicted Values')                                            # Add label to x-axis
      ax[0].set_ylabel('Actual Values')                                               # Add label to y-axis
    
    cm = confusion_matrix(y_cv, predict_with_best_t(y_cv_pred, best_t))               # Calculate count of the confusion matrix for CV Data
    with plt.style.context('seaborn'):                                                # Set the background for graph plotting 
      sns.heatmap(cm, annot=True, fmt='d', ax=ax[1], cmap='YlGnBu')                   # Plot Heatmap of CV Confusion Matrix
      ax[1].set_title('CV Confusion Matrix')                                          # Add title of the plot
      ax[1].set_xlabel('Predicted Values')                                            # Add label to x-axis
      ax[1].set_ylabel('Actual Values')                                               # Add label to x-axis
        
    plt.show()
    
    return predict_with_best_t(y_tr_pred, best_t), predict_with_best_t(y_cv_pred, best_t)

def model_validation(clf, x_tr, x_cv, y_tr, y_cv):
  '''Function takes classifier, train and cv data and returns the best threshhold, model auc and train/cv f1 score'''
  y_tr_pred = pred_proba(clf, x_tr)                                                   # function call
  y_cv_pred = pred_proba(clf, x_cv)                                                   # function call
  train_fpr, train_tpr, tr_thresholds = roc_curve(y_tr, y_tr_pred)                    # Calculate FPR and TPR for Train Data
  cv_fpr, cv_tpr, cv_thresholds = roc_curve(y_cv, y_cv_pred)                          # Calculate FPR and TPR for CV Data

  print('Train AUC = {}'.format(auc(train_fpr, train_tpr)))
  print('CV AUC = {}'.format(auc(cv_fpr, cv_tpr)))

  plt.plot(train_fpr, train_tpr, label="Train AUC ="+str(auc(train_fpr, train_tpr))) # Plot Train FPR and Train TPR
  plt.plot(cv_fpr, cv_tpr, label="CV AUC ="+str(auc(cv_fpr, cv_tpr)))                # Plot CV FPR and CV TPR
  plt.legend()                                                                       # Add legend to the plot
  plt.plot([0,1],[0,1], 'g-')                                                        # Plot a diagnol for random model
  plt.xlabel("False positive Rate(FPR)")                                             # Add label to x-axis
  plt.ylabel("True positive Rate(TPR)")                                              # Add label to y-axis
  plt.title("ROC Curve")                                                             # Add title of the plot
  plt.grid()                                                                         # Add grid to the plot
  plt.show()

  best_t = find_best_threshold(tr_thresholds, train_fpr, train_tpr)                  # function call
  tr_pred, cv_pred = plot_confusion_matrix(best_t, x_tr, x_cv, y_tr, y_cv, y_tr_pred, y_cv_pred)
  train_f1_score = f1_score(y_tr, tr_pred)                                           # calculate Train F1 score
  cv_f1_score = f1_score(y_cv, cv_pred)                                              # calculate cv F1 score

  return best_t, auc(cv_fpr, cv_tpr), train_f1_score, cv_f1_score

def imp_features(imp_feat, feat_weights, val, head):
  '''Function to predict the important features after applying a classification model on it'''
  feat_imp = pd.DataFrame(list(zip(imp_feat, feat_weights)), columns =['Features', 'Weights'])
  feat_imp = feat_imp[feat_imp['Weights'] != 0]                                     # Filter non zero weights of features with names
  feat_imp.reset_index(drop=True, inplace=True)

  best_worst_15_feat = feat_imp.sort_values(by= 'Weights',ascending=val)['Features'].iloc[0:15]
  best_worst_15_feat_weights = feat_imp.sort_values(by='Weights',ascending=val)['Weights'].iloc[0:15]
  feat_list = pd.DataFrame(list(zip(list(best_worst_15_feat), list(best_worst_15_feat_weights))), columns =['Features', 'Weights'])
  print(feat_list.head(15))

  with plt.style.context('seaborn-white'):                                          # Set the white background for graph plotting 
    plt.figure(figsize=(12, 8))
    sns.barplot(y=best_worst_15_feat, x=best_worst_15_feat_weights)                 # Bargraph with features and its weights
    plt.grid(linestyle="-")                                                         # Add grid to the plot
    plt.xlabel('Features Importance Weights')                                       # Add label to x-axis
    plt.ylabel('Features')                                                          # Add label to y-axis
    plt.title(head + 'Features')                                                    # Add title of the plot

  plt.show()

# %% [markdown]
# ### 3.1 Logistic Regression with hyperparameter tuning using Random Search CV

# %%
# Code Reference: https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html

reg_inv = np.logspace(-5,5,100)
print(reg_inv)
params ={'C':reg_inv, 'penalty':['l1','l2']}
model = LogisticRegression(tol=0.0001, 
                           fit_intercept=True, 
                           class_weight='balanced',
                           random_state=49,
                           solver='liblinear',
                           max_iter=500)

# Code Reference: https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html

search = RandomizedSearchCV(model, params, scoring='roc_auc', cv=5, return_train_score=True)
result = search.fit(X_train_std, y_train)

print('Best Hyperparameters: ',result.best_params_)
print('Best Score: ',result.best_score_)
# Out:
# [1.00000000e-05 1.26185688e-05 1.59228279e-05 2.00923300e-05
#  2.53536449e-05 3.19926714e-05 4.03701726e-05 5.09413801e-05
#  6.42807312e-05 8.11130831e-05 1.02353102e-04 1.29154967e-04
#  1.62975083e-04 2.05651231e-04 2.59502421e-04 3.27454916e-04
#  4.13201240e-04 5.21400829e-04 6.57933225e-04 8.30217568e-04
#  1.04761575e-03 1.32194115e-03 1.66810054e-03 2.10490414e-03
#  2.65608778e-03 3.35160265e-03 4.22924287e-03 5.33669923e-03
#  6.73415066e-03 8.49753436e-03 1.07226722e-02 1.35304777e-02
#  1.70735265e-02 2.15443469e-02 2.71858824e-02 3.43046929e-02
#  4.32876128e-02 5.46227722e-02 6.89261210e-02 8.69749003e-02
#  1.09749877e-01 1.38488637e-01 1.74752840e-01 2.20513074e-01
#  2.78255940e-01 3.51119173e-01 4.43062146e-01 5.59081018e-01
#  7.05480231e-01 8.90215085e-01 1.12332403e+00 1.41747416e+00
#  1.78864953e+00 2.25701972e+00 2.84803587e+00 3.59381366e+00
#  4.53487851e+00 5.72236766e+00 7.22080902e+00 9.11162756e+00
#  1.14975700e+01 1.45082878e+01 1.83073828e+01 2.31012970e+01
#  2.91505306e+01 3.67837977e+01 4.64158883e+01 5.85702082e+01
#  7.39072203e+01 9.32603347e+01 1.17681195e+02 1.48496826e+02
#  1.87381742e+02 2.36448941e+02 2.98364724e+02 3.76493581e+02
#  4.75081016e+02 5.99484250e+02 7.56463328e+02 9.54548457e+02
#  1.20450354e+03 1.51991108e+03 1.91791026e+03 2.42012826e+03
#  3.05385551e+03 3.85352859e+03 4.86260158e+03 6.13590727e+03
#  7.74263683e+03 9.77009957e+03 1.23284674e+04 1.55567614e+04
#  1.96304065e+04 2.47707636e+04 3.12571585e+04 3.94420606e+04
#  4.97702356e+04 6.28029144e+04 7.92482898e+04 1.00000000e+05]
# Best Hyperparameters:  {'penalty': 'l2', 'C': 0.44306214575838776}
# Best Score:  0.9316392990028817

# %% [markdown]
# #### 3.1.1 Fitting logistic regression with best hyperparameters

# %%
model1 = LogisticRegression(penalty='l2',
                            C=0.4430621,
                            tol=0.0001,
                            fit_intercept=True,
                            class_weight='balanced',
                            random_state=49,
                            solver='liblinear',  
                            max_iter=500)

model1.fit(X_train_std, y_train)

best_t, model_auc, train_f1_score, cv_f1_score = model_validation(model1, X_train_std, X_cv_std, y_train, y_cv)     # function call
print('Best Threshold = {:.4f}'.format(best_t))
print('Model AUC = {:.4f}'.format(model_auc))
print('Train F1 Score = {:.4f}'.format(train_f1_score))
print('CV F1 Score = {:.4f}'.format(cv_f1_score))
# Out:
# Train AUC = 0.9405512465419549
# CV AUC = 0.9532094171526709
# Best Threshold = 0.3709
# Model AUC = 0.9532
# Train F1 Score = 0.5751
# CV F1 Score = 0.6044

# %% [markdown]
# #### 3.1.2 Finding the most important features using logistic regression with best hyperparameters

# %%
feat_weights = list(model1.coef_[0])
imp_features(imp_feat, feat_weights, False, 'Most Important ')            # function call
# Out:
#                                              Features   Weights
# 0   mean_InscClaimAmtReimbursed_perOperatingPhysician  2.633486
# 1            mean_Hospital_Days_perAttendingPhysician  1.704703
# 2                     count_ClaimID_perProviderBeneID  1.657598
# 3       mean_InscClaimAmtReimbursed_perOtherPhysician  1.090961
# 4                         mean_Claim_Days_perProvider  0.995611
# 5                               RenalDiseaseIndicator  0.838229
# 6            mean_Hospital_Days_perOperatingPhysician  0.689480
# 7            mean_Hospital_Days_perClmDiagnosisCode_5  0.620868
# 8            mean_DeductibleAmtPaid_perOtherPhysician  0.604519
# 9            mean_Hospital_Days_perClmDiagnosisCode_9  0.580291
# 10           mean_Hospital_Days_perClmDiagnosisCode_8  0.494931
# 11        count_ClaimID_perProviderClmDiagnosisCode_4  0.485882
# 12            count_ClaimID_perProviderOtherPhysician  0.429020
# 13           mean_Hospital_Days_perClmDiagnosisCode_2  0.410700
# 14                                             Race_3  0.406880

# %% [markdown]
# #### 3.1.3 Finding the least important features using logistic regression with best hyperparameters

# %%
imp_features(imp_feat, feat_weights, True, 'Least Important ')           # function call
# Out:
#                                              Features   Weights
# 0            mean_Hospital_Days_perClmDiagnosisCode_3 -1.329666
# 1                   mean_Claim_Days_perOtherPhysician -1.322850
# 2                    mean_DeductibleAmtPaid_perBeneID -0.863485
# 3                mean_Hospital_Days_perOtherPhysician -0.858213
# 4                               ChronicCond_Alzheimer -0.802236
# 5               mean_Claim_Days_perClmDiagnosisCode_1 -0.736349
# 6        mean_DeductibleAmtPaid_perOperatingPhysician -0.638208
# 7            mean_Hospital_Days_perClmDiagnosisCode_4 -0.527985
# 8            mean_Hospital_Days_perClmProcedureCode_1 -0.517320
# 9                           mean_Claim_Days_perBeneID -0.508628
# 10          mean_Hospital_Days_perClmDiagnosisCode_10 -0.368669
# 11  mean_InscClaimAmtReimbursed_perClmDiagnosisCode_4 -0.361220
# 12  mean_IPAnnualReimbursementAmt_perClmDiagnosisC... -0.324472
# 13       mean_DeductibleAmtPaid_perClmDiagnosisCode_9 -0.291266
# 14  mean_InscClaimAmtReimbursed_perClmDiagnosisCode_6 -0.279045

# %% [markdown]
# #### 3.1.4 Summary of results

# %%
data = PrettyTable(['Model', 'Sampling Ratio', 'Solution for Imbalanced Data', 'Train AUC', 'CV AUC', 'Train F1 Score', 'CV F1 Score', 'False Negatives'])
data.add_row(['Logistic Regression', '70:30', 'Class Weight = Balanced', 0.9406, 0.9532, 0.5751, 0.6044, 16])

print(data)
# Out:
# +---------------------+----------------+------------------------------+-----------+--------+----------------+-------------+-----------------+
# |        Model        | Sampling Ratio | Solution for Imbalanced Data | Train AUC | CV AUC | Train F1 Score | CV F1 Score | False Negatives |
# +---------------------+----------------+------------------------------+-----------+--------+----------------+-------------+-----------------+
# | Logistic Regression |     70:30      |   Class Weight = Balanced    |   0.9406  | 0.9532 |     0.5751     |    0.6044   |        16       |
# +---------------------+----------------+------------------------------+-----------+--------+----------------+-------------+-----------------+

# %% [markdown]
# ### 3.2 Decision Trees with hyperparameter tuning using Random Search CV

# %%
model2 = DecisionTreeClassifier(class_weight = 'balanced', random_state=49)

params = {'criterion': ['gini','entropy'],
          'max_depth': [int(a) for a in (np.linspace(2, 512, 200))],
          'min_samples_split': [int(a) for a in (np.linspace(10, 900, 80))],
          'min_samples_leaf': [int(a) for a in (np.linspace(10, 900, 80))],
          'max_features':["auto", "sqrt", "log2"]}

search1 = RandomizedSearchCV(model2, params, scoring='roc_auc', cv=5, return_train_score=True)

result1 = search1.fit(X_train_std, y_train)

print("Best Hyperparameters: ",result1.best_params_)
print("Best Score: ",result1.best_score_)
# Out:
# Best Hyperparameters:  {'min_samples_split': 122, 'min_samples_leaf': 280, 'max_features': 'auto', 'max_depth': 178, 'criterion': 'gini'}
# Best Score:  0.9089095294220243

# %% [markdown]
# #### 3.2.1 Fitting decision trees with best hyperparameters

# %%
model3 = DecisionTreeClassifier(criterion='gini',
                                max_depth= 178,
                                min_samples_split=122,
                                min_samples_leaf=280,
                                max_features='auto',
                                random_state=49,
                                class_weight='balanced')

model3.fit(X_train_std, y_train)

best_t, model_auc, train_f1_score, cv_f1_score = model_validation(model3, X_train_std, X_cv_std, y_train, y_cv)     # function call
print('Best Threshold = {:.4f}'.format(best_t))
print('Model AUC = {:.4f}'.format(model_auc))
print('Train F1 Score = {:.4f}'.format(train_f1_score))
print('CV F1 Score = {:.4f}'.format(cv_f1_score))
# Out:
# Train AUC = 0.9250795288665511
# CV AUC = 0.9281056567319044
# Best Threshold = 0.7461
# Model AUC = 0.9281
# Train F1 Score = 0.5307
# CV F1 Score = 0.5473

# %% [markdown]
# #### 3.2.2 Finding the most important features using decision trees with best hyperparameters

# %%
feat_weights = list(model3.feature_importances_)

imp_features(imp_feat, feat_weights, False, 'Most Important ')            # function call
# Out:
#                                             Features   Weights
# 0           mean_Hospital_Days_perOperatingPhysician  0.899431
# 1           mean_Hospital_Days_perClmDiagnosisCode_5  0.031966
# 2       mean_DeductibleAmtPaid_perOperatingPhysician  0.029752
# 3                              ChronicCond_Alzheimer  0.023167
# 4                           ChronicCond_Osteoporasis  0.008496
# 5  mean_InscClaimAmtReimbursed_perClmDiagnosisCode_6  0.006702
# 6                             ChronicCond_Depression  0.000485

# %% [markdown]
# #### 3.2.3 Finding the least important features using decision trees with best hyperparameters

# %%
imp_features(imp_feat, feat_weights, True, 'Least Important ')           # function call
# Out:
#                                             Features   Weights
# 0                             ChronicCond_Depression  0.000485
# 1  mean_InscClaimAmtReimbursed_perClmDiagnosisCode_6  0.006702
# 2                           ChronicCond_Osteoporasis  0.008496
# 3                              ChronicCond_Alzheimer  0.023167
# 4       mean_DeductibleAmtPaid_perOperatingPhysician  0.029752
# 5           mean_Hospital_Days_perClmDiagnosisCode_5  0.031966
# 6           mean_Hospital_Days_perOperatingPhysician  0.899431

# %% [markdown]
# #### 3.2.4 Summary of results and its comparison with other models

# %%
data.add_row(['Decision Trees', '70:30', 'Class Weight = Balanced', 0.9251, 0.9281, 0.5307, 0.5473, 16])

print(data)
# Out:
# +---------------------+----------------+------------------------------+-----------+--------+----------------+-------------+-----------------+
# |        Model        | Sampling Ratio | Solution for Imbalanced Data | Train AUC | CV AUC | Train F1 Score | CV F1 Score | False Negatives |
# +---------------------+----------------+------------------------------+-----------+--------+----------------+-------------+-----------------+
# | Logistic Regression |     70:30      |   Class Weight = Balanced    |   0.9406  | 0.9532 |     0.5751     |    0.6044   |        16       |
# |    Decision Trees   |     70:30      |   Class Weight = Balanced    |   0.9251  | 0.9281 |     0.5307     |    0.5473   |        16       |
# +---------------------+----------------+------------------------------+-----------+--------+----------------+-------------+-----------------+

# %% [markdown]
# ### 3.3 XGB Classifier with hyperparameter tuning using Random Search CV

# %%
model4 = XGBClassifier(tree_method = 'hist')

params = {'n_estimators': [int(a) for a in (np.linspace(10, 500, 250))],
          'max_depth': [int(a) for a in (np.linspace(2, 512, 200))],
          'colsample_bytree': list(np.linspace(0.5, 1, 25)),
          'reg_alpha': [int(a) for a in (np.linspace(0, 100, 25))],
          'reg_lambda': [int(a) for a in (np.linspace(0, 100, 25))],
          'scale_pos_weight':[3.11, 9.69]}


search2 = RandomizedSearchCV(model4, params, scoring='roc_auc', cv=5, refit='recall', return_train_score=True)
result2 = search2.fit(X_train_std, y_train)

print("Best Hyperparameters: ",result2.best_params_)
print("Best Score: ",result2.best_score_)
# Out:
# Best Hyperparameters:  {'scale_pos_weight': 3.11, 'reg_lambda': 33, 'reg_alpha': 16, 'n_estimators': 263, 'max_depth': 104, 'colsample_bytree': 0.8333333333333333}
# Best Score:  0.9256699230525595

# %% [markdown]
# #### 3.3.1 Fitting XGB Classifier with best hyperparameters

# %%
model5 = XGBClassifier(n_estimators=263,
                       max_depth= 104,
                       colsample_bytree=0.83333,
                       reg_alpha=16,
                       reg_lambda=33,
                       random_state=49,
                       scale_pos_weight = 3.11)

model5.fit(X_train_std, y_train)

best_t, model_auc, train_f1_score, cv_f1_score = model_validation(model5, X_train_std, X_cv_std, y_train, y_cv)       # function call
print('Best Threshold = {:.4f}'.format(best_t))
print('Model AUC = {:.4f}'.format(model_auc))
print('Train F1 Score = {:.4f}'.format(train_f1_score))
print('CV F1 Score = {:.4f}'.format(cv_f1_score))
# Out:
# Train AUC = 0.983863827490245
# CV AUC = 0.9498550932054814
# Best Threshold = 0.4335
# Model AUC = 0.9499
# Train F1 Score = 0.7860
# CV F1 Score = 0.6431

# %% [markdown]
# #### 3.3.2 Finding the most important features using XGB Classifier with best hyperparameters

# %%
feat_weights = list(model5.feature_importances_)

imp_features(imp_feat, feat_weights, False, 'Most Important ')            # function call
# Out:
#                                              Features   Weights
# 0            mean_Hospital_Days_perOperatingPhysician  0.581413
# 1            mean_Hospital_Days_perClmProcedureCode_1  0.078815
# 2        mean_DeductibleAmtPaid_perAttendingPhysician  0.056873
# 3   mean_InscClaimAmtReimbursed_perOperatingPhysician  0.020374
# 4            mean_Hospital_Days_perAttendingPhysician  0.017981
# 5                     count_ClaimID_perProviderBeneID  0.013851
# 6           mean_Hospital_Days_perClmDiagnosisCode_10  0.010220
# 7                          ChronicCond_ObstrPulmonary  0.009820
# 8               mean_InscClaimAmtReimbursed_perBeneID  0.009811
# 9            mean_Hospital_Days_perClmDiagnosisCode_9  0.008760
# 10                                         Difference  0.007570
# 11                             ChronicCond_Depression  0.007393
# 12                                             Race_2  0.006984
# 13           mean_Hospital_Days_perClmDiagnosisCode_5  0.006813
# 14                                 ChronicCond_stroke  0.006624

# %% [markdown]
# #### 3.3.3 Finding the least important features using XGB Classifier with best hyperparameters

# %%
imp_features(imp_feat, feat_weights, True, 'Least Important ')           # function call
# Out:
#                                              Features   Weights
# 0        mean_IPAnnualDeductibleAmt_perOtherPhysician  0.001870
# 1                            ChronicCond_Osteoporasis  0.002660
# 2   mean_IPAnnualReimbursementAmt_perClmDiagnosisC...  0.002920
# 3            mean_Hospital_Days_perClmDiagnosisCode_2  0.002998
# 4            mean_DeductibleAmtPaid_perOtherPhysician  0.003019
# 5                               ChronicCond_Alzheimer  0.003114
# 6                mean_Hospital_Days_perOtherPhysician  0.003169
# 7            mean_Hospital_Days_perClmDiagnosisCode_3  0.003229
# 8             count_ClaimID_perProviderOtherPhysician  0.003355
# 9                           ChronicCond_KidneyDisease  0.003653
# 10                                 ChronicCond_Cancer  0.003676
# 11                                           Gender_1  0.003715
# 12                  mean_Claim_Days_perOtherPhysician  0.003952
# 13        count_ClaimID_perProviderClmDiagnosisCode_4  0.004043
# 14           mean_Hospital_Days_perClmDiagnosisCode_6  0.004131

# %% [markdown]
# #### 3.3.4 Summary of results and its comparison with other models

# %%
data.add_row(['XGBoost Classifier', '70:30', 'Scale Positive Weight', 0.9839, 0.9499, 0.7860, 0.6431, 34])

print(data)
# Out:
# +---------------------+----------------+------------------------------+-----------+--------+----------------+-------------+-----------------+
# |        Model        | Sampling Ratio | Solution for Imbalanced Data | Train AUC | CV AUC | Train F1 Score | CV F1 Score | False Negatives |
# +---------------------+----------------+------------------------------+-----------+--------+----------------+-------------+-----------------+
# | Logistic Regression |     70:30      |   Class Weight = Balanced    |   0.9406  | 0.9532 |     0.5751     |    0.6044   |        16       |
# |    Decision Trees   |     70:30      |   Class Weight = Balanced    |   0.9251  | 0.9281 |     0.5307     |    0.5473   |        16       |
# |  XGBoost Classifier |     70:30      |    Scale Positive Weight     |   0.9839  | 0.9499 |     0.786      |    0.6431   |        34       |
# +---------------------+----------------+------------------------------+-----------+--------+----------------+-------------+-----------------+

# %% [markdown]
# ## 4. Loading Data
#
# ### 4.1 Splitting and scaling data into Train and Cross Validation(or Test)
#
# #### 4.1.1 Stratified Sampling(80:20)

# %%
X_train_std, X_cv_std, y_train, y_cv, X_train_df, X_cv_df = train_cv_split_scaling(X, y, 0.20)         # function call
fraud_per(y_train)                                                                                     # function call
# Out:
# X_train Shape =  (4328, 285)
# X_cv Shape =  (1082, 285)
# Y_train Shape =  (4328,)
# Y_cv Shape =  (1082,)
# Fraud Percentage = 9.36%
# Non-Fraud Percentage = 90.64%

# %% [markdown]
# ### 4.2 Perform Dimensionality Reduction Techniques
#
# #### 4.2.1 Plot TSNE for Train Data (285 dimensions reduced to 2 dimension)

# %%
plot_TSNE(X_train_std, y_train)                                         # function call

# %% [markdown]
# #### 4.2.2 Perform PCA for Feature Reduction

# %%
feat_reduct_PCA(X_train_std, X_cv_std, y_cv)                           # function call
# Out:
# AUROC scores for different values of features:
#  [0.9050336682896509, 0.9119458791493391, 0.9098337304464934, 0.9086758742655873, 0.9083811225723066, 0.9089007858400795, 0.9093502513405654, 0.9091925900164272, 0.908990419953333, 0.9091947605728297, 0.9090997493993971, 0.908997967569914, 0.9091947605728297, 0.9091464286947556, 0.909049246964921, 0.9091439991515099, 0.9092919423026643, 0.9090443878784292, 0.9088456833059547, 0.9093016604756479, 0.9090468174216749, 0.9092457809809928, 0.9093966716490802, 0.9092994899192455, 0.9091950195596731, 0.9091391400650182]

# %% [markdown]
# #### 4.2.3 Replace Train and CV(Test) Data with the best features

# %%
imp_feat, X_train_std, X_cv_std = feat_after_reduction(40, X_train_std, X, X_train_df, X_cv_df)         # function call
# Out:
# Explained Variance using PCA with randomized svd_solver:
#  [8.80645223e-01 7.97950865e-02 2.91801872e-02 3.37547333e-03
#  1.47755314e-03 8.14285439e-04 7.81602778e-04 5.11610419e-04
#  4.55513793e-04 3.38165478e-04 3.10312925e-04 2.66482400e-04
#  1.92167659e-04 1.57147934e-04 1.46997005e-04 1.27901506e-04
#  1.18156487e-04 1.04686257e-04 9.02939860e-05 7.60360611e-05
#  7.09398597e-05 6.47652958e-05 5.93761699e-05 5.27620050e-05
#  4.44571859e-05 4.36023777e-05 4.26344109e-05 3.87154456e-05
#  3.53027182e-05 3.35564305e-05 3.21439132e-05 3.09132788e-05
#  2.99041919e-05 2.69262301e-05 2.59087062e-05 2.50631228e-05
#  2.41708240e-05 2.23139032e-05 1.89314834e-05 1.74521915e-05]
# 100%|██████████| 40/40 [00:00<00:00, 5527.18it/s]
# Unique Feature Names with best Explained Variance Ratio:
#  ['mean_IPAnnualReimbursementAmt_perClmDiagnosisCode_7', 'mean_Claim_Days_perClmDiagnosisCode_2', 'mean_Hospital_Days_perClmDiagnosisCode_5', 'Gender_1', 'mean_OPAnnualReimbursementAmt_perProvider', 'Gender_0', 'Race_3', 'mean_Hospital_Days_perOtherPhysician', 'ChronicCond_ObstrPulmonary', 'mean_Hospital_Days_perClmDiagnosisCode_2', 'mean_Hospital_Days_perAttendingPhysician', 'mean_Claim_Days_perProvider', 'mean_DeductibleAmtPaid_perAttendingPhysician', 'mean_Hospital_Days_perClmDiagnosisCode_9', 'mean_IPAnnualReimbursementAmt_perProvider', 'RenalDiseaseIndicator', 'ChronicCond_stroke', 'count_ClaimID_perProviderDiagnosisGroupCode', 'Race_5', 'mean_DeductibleAmtPaid_perOperatingPhysician', 'Difference', 'mean_DeductibleAmtPaid_perClmAdmitDiagnosisCode', 'ChronicCond_Osteoporasis', 'mean_Hospital_Days_perClmProcedureCode_2', 'count_ClaimID_perProviderAttendingPhysician', 'count_ClaimID_perProviderClmDiagnosisCode_4', 'count_ClaimID_perProviderBeneID', 'mean_Hospital_Days_perBeneID', 'mean_Hospital_Days_perOperatingPhysician', 'mean_DeductibleAmtPaid_perOtherPhysician', 'ChronicCond_Depression', 'Race_2', 'mean_Hospital_Days_perClmDiagnosisCode_1', 'mean_Hospital_Days_perClmDiagnosisCode_3', 'mean_Hospital_Days_perClmDiagnosisCode_4', 'mean_Hospital_Days_perClmDiagnosisCode_6', 'mean_InscClaimAmtReimbursed_perClmDiagnosisCode_9', 'mean_InscClaimAmtReimbursed_perClmDiagnosisCode_5', 'mean_Hospital_Days_perProvider', 'mean_Hospital_Days_perClmProcedureCode_1']
# Final X_train Shape =  (4328, 40)
# Final X_cv Shape =  (1082, 40)

# %% [markdown]
# #### 4.2.4 Store the Train and CV(Test) Data as csv for future use

# %%
X_train_std_df = pd.DataFrame(X_train_std, columns=imp_feat)                   # store Final X_train as dataframe 
X_cv_std_df = pd.DataFrame(X_cv_std, columns=imp_feat)                         # store Final X_cv as dataframe 
x_pf = pd.DataFrame(y_train, columns = ['PotentialFraud'])
X_train_std_df['PotentialFraud'] = list(x_pf['PotentialFraud'])                # store y_train in Final X_train dataframe
x_pf = pd.DataFrame(y_cv, columns = ['PotentialFraud'])
X_cv_std_df['PotentialFraud'] = list(x_pf['PotentialFraud'])                   # store y_cv in Final X_cv dataframe

X_train_std_df.to_csv('Final_train2.csv', index = False)                       # store important features as csv for X_train
X_cv_std_df.to_csv('Final_cv2.csv', index = False)                             # store important features as csv for X_cv

# %% [markdown]
# ## 5. Modelling with Class Weight = 'Balanced'

# %% [markdown]
# ### 5.1 Fitting logistic regression with best hyperparameters

# %%
model1 = LogisticRegression(penalty='l2',
                            C=0.4430621,
                            tol=0.0001,
                            fit_intercept=True,
                            class_weight='balanced',
                            random_state=49,
                            solver='liblinear',  
                            max_iter=500)

model1.fit(X_train_std, y_train)

best_t, model_auc, train_f1_score, cv_f1_score = model_validation(model1, X_train_std, X_cv_std, y_train, y_cv)      # function call
print('Best Threshold = {:.4f}'.format(best_t))
print('Model AUC = {:.4f}'.format(model_auc))
print('Train F1 Score = {:.4f}'.format(train_f1_score))
print('CV F1 Score = {:.4f}'.format(cv_f1_score))
# Out:
# Train AUC = 0.9434704481012579
# CV AUC = 0.9482342729685812
# Best Threshold = 0.4236
# Model AUC = 0.9482
# Train F1 Score = 0.6103
# CV F1 Score = 0.5979

# %% [markdown]
# #### 5.1.1 Finding the most important features using logistic regression with best hyperparameters

# %%
feat_weights = list(model1.coef_[0])

imp_features(imp_feat, feat_weights, False, 'Most Important ')        # function call
# Out:
#                                              Features   Weights
# 0                      mean_Hospital_Days_perProvider  2.479000
# 1                     count_ClaimID_perProviderBeneID  1.585827
# 2   mean_InscClaimAmtReimbursed_perClmDiagnosisCode_5  0.995644
# 3            mean_DeductibleAmtPaid_perOtherPhysician  0.915326
# 4            mean_Hospital_Days_perAttendingPhysician  0.835897
# 5                               RenalDiseaseIndicator  0.795052
# 6            mean_Hospital_Days_perOperatingPhysician  0.725985
# 7            mean_Hospital_Days_perClmDiagnosisCode_9  0.631364
# 8            mean_Hospital_Days_perClmProcedureCode_2  0.606422
# 9           mean_IPAnnualReimbursementAmt_perProvider  0.548731
# 10           mean_Hospital_Days_perClmDiagnosisCode_5  0.548685
# 11        count_ClaimID_perProviderClmDiagnosisCode_4  0.522942
# 12           mean_Hospital_Days_perClmDiagnosisCode_2  0.444753
# 13    mean_DeductibleAmtPaid_perClmAdmitDiagnosisCode  0.433466
# 14        count_ClaimID_perProviderDiagnosisGroupCode  0.370266

# %% [markdown]
# #### 5.1.2 Finding the least important features using logistic regression with best hyperparameters

# %%
imp_features(imp_feat, feat_weights, True, 'Least Important ')         # function call
# Out:
#                                              Features   Weights
# 0            mean_Hospital_Days_perClmDiagnosisCode_3 -1.431553
# 1                mean_Hospital_Days_perOtherPhysician -0.977838
# 2                                            Gender_0 -0.921287
# 3            mean_Hospital_Days_perClmDiagnosisCode_1 -0.753168
# 4            mean_Hospital_Days_perClmDiagnosisCode_4 -0.626537
# 5            mean_Hospital_Days_perClmDiagnosisCode_6 -0.608333
# 6        mean_DeductibleAmtPaid_perAttendingPhysician -0.565975
# 7                                            Gender_1 -0.512054
# 8   mean_InscClaimAmtReimbursed_perClmDiagnosisCode_9 -0.389818
# 9                        mean_Hospital_Days_perBeneID -0.385710
# 10  mean_IPAnnualReimbursementAmt_perClmDiagnosisC... -0.365965
# 11                                             Race_2 -0.326657
# 12              mean_Claim_Days_perClmDiagnosisCode_2 -0.153694
# 13                         ChronicCond_ObstrPulmonary -0.053671
# 14       mean_DeductibleAmtPaid_perOperatingPhysician -0.044203

# %% [markdown]
# #### 5.1.3 Summary of results and its comparison with other models

# %%
data.add_row(['Logistic Regression', '80:20', 'Class Weight = Balanced', 0.9435, 0.9482, 0.6103, 0.5979, 17])

print(data)
# Out:
# +---------------------+----------------+------------------------------+-----------+--------+----------------+-------------+-----------------+
# |        Model        | Sampling Ratio | Solution for Imbalanced Data | Train AUC | CV AUC | Train F1 Score | CV F1 Score | False Negatives |
# +---------------------+----------------+------------------------------+-----------+--------+----------------+-------------+-----------------+
# | Logistic Regression |     70:30      |   Class Weight = Balanced    |   0.9406  | 0.9532 |     0.5751     |    0.6044   |        16       |
# |    Decision Trees   |     70:30      |   Class Weight = Balanced    |   0.9251  | 0.9281 |     0.5307     |    0.5473   |        16       |
# |  XGBoost Classifier |     70:30      |    Scale Positive Weight     |   0.9839  | 0.9499 |     0.786      |    0.6431   |        34       |
# | Logistic Regression |     80:20      |   Class Weight = Balanced    |   0.9435  | 0.9482 |     0.6103     |    0.5979   |        17       |
# +---------------------+----------------+------------------------------+-----------+--------+----------------+-------------+-----------------+

# %% [markdown]
# ### 5.2 Fitting decision trees with best hyperparameters

# %%
model3 = DecisionTreeClassifier(criterion='gini',
                                max_depth= 178,
                                min_samples_split=122,
                                min_samples_leaf=280,
                                max_features='auto',
                                random_state=49,
                                class_weight='balanced')

model3.fit(X_train_std, y_train)

best_t, model_auc, train_f1_score, cv_f1_score = model_validation(model3, X_train_std, X_cv_std, y_train, y_cv)      # function call
print('Best Threshold = {:.4f}'.format(best_t))
print('Model AUC = {:.4f}'.format(model_auc))
print('Train F1 Score = {:.4f}'.format(train_f1_score))
print('CV F1 Score = {:.4f}'.format(cv_f1_score))
# Out:
# Train AUC = 0.9235829848031394
# CV AUC = 0.9155892653485531
# Best Threshold = 0.8165
# Model AUC = 0.9156
# Train F1 Score = 0.5830
# CV F1 Score = 0.5843

# %% [markdown]
# #### 5.2.1 Finding the most important features using decision trees with best hyperparameters

# %%
feat_weights = list(model3.feature_importances_)

imp_features(imp_feat, feat_weights, False, 'Most Important ')              # function call
# Out:
#                                             Features   Weights
# 0           mean_Hospital_Days_perClmDiagnosisCode_5  0.811504
# 1           mean_Hospital_Days_perOperatingPhysician  0.087490
# 2  mean_InscClaimAmtReimbursed_perClmDiagnosisCode_9  0.039267
# 3                                           Gender_0  0.037700
# 4           mean_Hospital_Days_perClmDiagnosisCode_6  0.013721
# 5           mean_Hospital_Days_perAttendingPhysician  0.007760
# 6           mean_Hospital_Days_perClmProcedureCode_2  0.001561
# 7        count_ClaimID_perProviderClmDiagnosisCode_4  0.000772
# 8           mean_Hospital_Days_perClmDiagnosisCode_3  0.000225

# %% [markdown]
# #### 5.2.2 Finding the least important features using decision trees with best hyperparameters

# %%
imp_features(imp_feat, feat_weights, True, 'Least Important ')         # function call
# Out:
#                                             Features   Weights
# 0           mean_Hospital_Days_perClmDiagnosisCode_3  0.000225
# 1        count_ClaimID_perProviderClmDiagnosisCode_4  0.000772
# 2           mean_Hospital_Days_perClmProcedureCode_2  0.001561
# 3           mean_Hospital_Days_perAttendingPhysician  0.007760
# 4           mean_Hospital_Days_perClmDiagnosisCode_6  0.013721
# 5                                           Gender_0  0.037700
# 6  mean_InscClaimAmtReimbursed_perClmDiagnosisCode_9  0.039267
# 7           mean_Hospital_Days_perOperatingPhysician  0.087490
# 8           mean_Hospital_Days_perClmDiagnosisCode_5  0.811504

# %% [markdown]
# #### 5.2.3 Summary of results and its comparison with other models

# %%
data.add_row(['Decision Trees', '80:20', 'Class Weight = Balanced', 0.9236, 0.9156, 0.5830, 0.5843, 23])

print(data)
# Out:
# +---------------------+----------------+------------------------------+-----------+--------+----------------+-------------+-----------------+
# |        Model        | Sampling Ratio | Solution for Imbalanced Data | Train AUC | CV AUC | Train F1 Score | CV F1 Score | False Negatives |
# +---------------------+----------------+------------------------------+-----------+--------+----------------+-------------+-----------------+
# | Logistic Regression |     70:30      |   Class Weight = Balanced    |   0.9406  | 0.9532 |     0.5751     |    0.6044   |        16       |
# |    Decision Trees   |     70:30      |   Class Weight = Balanced    |   0.9251  | 0.9281 |     0.5307     |    0.5473   |        16       |
# |  XGBoost Classifier |     70:30      |    Scale Positive Weight     |   0.9839  | 0.9499 |     0.786      |    0.6431   |        34       |
# | Logistic Regression |     80:20      |   Class Weight = Balanced    |   0.9435  | 0.9482 |     0.6103     |    0.5979   |        17       |
# |    Decision Trees   |     80:20      |   Class Weight = Balanced    |   0.9236  | 0.9156 |     0.583      |    0.5843   |        23       |
# +---------------------+----------------+------------------------------+-----------+--------+----------------+-------------+-----------------+

# %% [markdown]
# ### 5.3 Fitting XGB Classifier with best hyperparameters

# %%
model5 = XGBClassifier(n_estimators=263,
                       max_depth= 104,
                       colsample_bytree=0.83333,
                       reg_alpha=16,
                       reg_lambda=33,
                       random_state=49,
                       scale_pos_weight= 3.11)

model5.fit(X_train_std, y_train)

best_t, model_auc, train_f1_score, cv_f1_score = model_validation(model5, X_train_std, X_cv_std, y_train, y_cv)         # function call
print('Best Threshold = {:.4f}'.format(best_t))
print('Model AUC = {:.4f}'.format(model_auc))
print('Train F1 Score = {:.4f}'.format(train_f1_score))
print('CV F1 Score = {:.4f}'.format(cv_f1_score))
# Out:
# Train AUC = 0.9821558834729027
# CV AUC = 0.9425621461228693
# Best Threshold = 0.4548
# Model AUC = 0.9426
# Train F1 Score = 0.7954
# CV F1 Score = 0.5917

# %% [markdown]
# #### 5.3.1 Finding the most important features using XGB Classifier with best hyperparameters

# %%
feat_weights = list(model5.feature_importances_)

imp_features(imp_feat, feat_weights, False, 'Most Important ')             # function call
# Out:
#                                              Features   Weights
# 0            mean_Hospital_Days_perOperatingPhysician  0.560009
# 1            mean_Hospital_Days_perClmProcedureCode_1  0.123311
# 2        mean_DeductibleAmtPaid_perAttendingPhysician  0.045418
# 3                      mean_Hospital_Days_perProvider  0.037667
# 4   mean_InscClaimAmtReimbursed_perClmDiagnosisCode_5  0.019344
# 5            mean_Hospital_Days_perClmDiagnosisCode_9  0.017375
# 6        mean_DeductibleAmtPaid_perOperatingPhysician  0.014679
# 7                     count_ClaimID_perProviderBeneID  0.012359
# 8            mean_Hospital_Days_perAttendingPhysician  0.008368
# 9            mean_Hospital_Days_perClmDiagnosisCode_4  0.008063
# 10           mean_Hospital_Days_perClmDiagnosisCode_1  0.007866
# 11        count_ClaimID_perProviderDiagnosisGroupCode  0.007483
# 12                                         Difference  0.006986
# 13           mean_Hospital_Days_perClmDiagnosisCode_5  0.006952
# 14                                 ChronicCond_stroke  0.006870

# %% [markdown]
# #### 5.3.2 Finding the least important features using XGB Classifier with best hyperparameters

# %%
imp_features(imp_feat, feat_weights, True, 'Least Important ')         # function call
# Out:
#                                              Features   Weights
# 0   mean_IPAnnualReimbursementAmt_perClmDiagnosisC...  0.002713
# 1               mean_Claim_Days_perClmDiagnosisCode_2  0.003053
# 2            mean_Hospital_Days_perClmDiagnosisCode_2  0.003271
# 3                                            Gender_1  0.003733
# 4                            ChronicCond_Osteoporasis  0.003740
# 5                              ChronicCond_Depression  0.003774
# 6            mean_Hospital_Days_perClmDiagnosisCode_3  0.003858
# 7         count_ClaimID_perProviderClmDiagnosisCode_4  0.004115
# 8                mean_Hospital_Days_perOtherPhysician  0.004320
# 9                                              Race_3  0.004330
# 10        count_ClaimID_perProviderAttendingPhysician  0.004399
# 11                       mean_Hospital_Days_perBeneID  0.004706
# 12          mean_IPAnnualReimbursementAmt_perProvider  0.004800
# 13                                           Gender_0  0.004878
# 14           mean_DeductibleAmtPaid_perOtherPhysician  0.004884

# %% [markdown]
# #### 5.3.3 Summary of results and its comparison with other models

# %%
data.add_row(['XGBoost Classifier', '80:20', 'Scale Positive Weight', 0.9822, 0.9426, 0.7954, 0.5917, 30])

print(data)
# Out:
# +---------------------+----------------+------------------------------+-----------+--------+----------------+-------------+-----------------+
# |        Model        | Sampling Ratio | Solution for Imbalanced Data | Train AUC | CV AUC | Train F1 Score | CV F1 Score | False Negatives |
# +---------------------+----------------+------------------------------+-----------+--------+----------------+-------------+-----------------+
# | Logistic Regression |     70:30      |   Class Weight = Balanced    |   0.9406  | 0.9532 |     0.5751     |    0.6044   |        16       |
# |    Decision Trees   |     70:30      |   Class Weight = Balanced    |   0.9251  | 0.9281 |     0.5307     |    0.5473   |        16       |
# |  XGBoost Classifier |     70:30      |    Scale Positive Weight     |   0.9839  | 0.9499 |     0.786      |    0.6431   |        34       |
# | Logistic Regression |     80:20      |   Class Weight = Balanced    |   0.9435  | 0.9482 |     0.6103     |    0.5979   |        17       |
# |    Decision Trees   |     80:20      |   Class Weight = Balanced    |   0.9236  | 0.9156 |     0.583      |    0.5843   |        23       |
# |  XGBoost Classifier |     80:20      |    Scale Positive Weight     |   0.9822  | 0.9426 |     0.7954     |    0.5917   |        30       |
# +---------------------+----------------+------------------------------+-----------+--------+----------------+-------------+-----------------+

# %% [markdown]
# ## 6. Loading Data
#
# ### 6.1 Splitting and scaling data into Train and Cross Validation(or Test)
#
# #### 6.1.1 Stratified Sampling(70:30)

# %%
X_train_std, X_cv_std, y_train, y_cv, X_train_df, X_cv_df = train_cv_split_scaling(X, y, 0.30)       # function call
# Out:
# X_train Shape =  (3787, 285)
# X_cv Shape =  (1623, 285)
# Y_train Shape =  (3787,)
# Y_cv Shape =  (1623,)

# %% [markdown]
# ### 6.2 SMOTE Sampling(70:30) for Imbalanced Data

# %%
# Code Reference: https://machinelearningmastery.com/smote-oversampling-for-imbalanced-classification/

oversample = SMOTE(sampling_strategy=0.428)
X_train_sample, y_train = oversample.fit_resample(X_train_std, y_train)
print(X_train_sample.shape, y_train.shape)
fraud_per(y_train)
# Out:
# (4902, 285) (4902,)
# Fraud Percentage = 29.97%
# Non-Fraud Percentage = 70.03%

# %% [markdown]
# ### 6.3 Perform Dimensionality Reduction Techniques
#
# #### 6.3.1 Plot TSNE for Train Data (285 dimensions reduced to 2 dimension)

# %%
plot_TSNE(X_train_sample, y_train)                                               # function call

# %% [markdown]
# #### 6.3.2 Perform PCA for Feature Reduction

# %%
feat_reduct_PCA(X_train_sample, X_cv_std, y_cv)                                   # function call
# Out:
# AUROC scores for different values of features:
#  [0.9353812511700508, 0.9387995125150479, 0.9388282334621474, 0.938128404924937, 0.937021682666141, 0.9363033738372332, 0.9364450494613739, 0.936632884901728, 0.9365406421362057, 0.9365201608254019, 0.9364970610806743, 0.9364756176937696, 0.9365211229015025, 0.9363865314305055, 0.9364523642152323, 0.93663419411869, 0.9365416042123064, 0.9365650114246538, 0.9364961758714786, 0.9364999101153128, 0.936339640138906, 0.9363851453466386, 0.9363170412688493, 0.936544299513135, 0.9364318829044285, 0.9364531725575231]

# %% [markdown]
# #### 6.3.3 Replace Train and CV(Test) Data with the best features

# %%
X_train_df = pd.DataFrame(X_train_sample, columns=X.columns)
X_cv_df = pd.DataFrame(X_cv_std, columns=X.columns)
print(X_train_df.shape, X_cv_df.shape)

imp_feat, X_train_std, X_cv_std = feat_after_reduction(50, X_train_sample, X, X_train_df, X_cv_df)       # function call
# Out:
# (4902, 285) (1623, 285)
# Explained Variance using PCA with randomized svd_solver:
#  [8.91659633e-01 8.32592322e-02 1.49897726e-02 4.05063296e-03
#  1.68282398e-03 1.04548285e-03 6.01473339e-04 3.71196414e-04
#  3.41068309e-04 2.37858930e-04 2.26241665e-04 1.99499847e-04
#  1.21399476e-04 1.15999841e-04 1.01635343e-04 9.68640341e-05
#  8.20650325e-05 6.74968895e-05 5.58630841e-05 5.09753615e-05
#  4.52313091e-05 4.15115741e-05 3.85250425e-05 3.45816404e-05
#  2.99108913e-05 2.80702848e-05 2.57761228e-05 2.42100753e-05
#  2.18759045e-05 2.08393428e-05 1.99551961e-05 1.86719022e-05
#  1.82061652e-05 1.77383676e-05 1.55511136e-05 1.48188562e-05
#  1.34490891e-05 1.27060394e-05 1.23646524e-05 1.17039323e-05
#  1.02991980e-05 8.97140835e-06 8.29259699e-06 7.72178278e-06
#  7.27931839e-06 6.37248170e-06 6.32475731e-06 6.21353053e-06
#  5.90850502e-06 5.52945982e-06]
# 100%|██████████| 50/50 [00:00<00:00, 10036.62it/s]
# Unique Feature Names with best Explained Variance Ratio:
#  ['mean_InscClaimAmtReimbursed_perClmProcedureCode_2', 'mean_Hospital_Days_perClmDiagnosisCode_5', 'Gender_1', 'Gender_0', 'Race_3', 'mean_InscClaimAmtReimbursed_perClmDiagnosisCode_3', 'mean_DeductibleAmtPaid_perBeneID', 'mean_Hospital_Days_perOtherPhysician', 'mean_InscClaimAmtReimbursed_perClmProcedureCode_1', 'ChronicCond_ObstrPulmonary', 'OPAnnualReimbursementAmt', 'mean_Hospital_Days_perClmDiagnosisCode_2', 'mean_Hospital_Days_perAttendingPhysician', 'ChronicCond_KidneyDisease', 'count_ClaimID_perProviderClmDiagnosisCode_1', 'mean_Hospital_Days_perClmDiagnosisCode_10', 'mean_Claim_Days_perProvider', 'ChronicCond_Alzheimer', 'mean_Claim_Days_perOperatingPhysician', 'mean_DeductibleAmtPaid_perAttendingPhysician', 'mean_Hospital_Days_perClmDiagnosisCode_9', 'RenalDiseaseIndicator', 'ChronicCond_stroke', 'mean_IPAnnualReimbursementAmt_perOperatingPhysician', 'Race_5', 'mean_DeductibleAmtPaid_perOperatingPhysician', 'Difference', 'mean_DeductibleAmtPaid_perClmAdmitDiagnosisCode', 'mean_InscClaimAmtReimbursed_perOtherPhysician', 'count_ClaimID_perProviderAttendingPhysician', 'mean_Hospital_Days_perClmProcedureCode_2', 'mean_Hospital_Days_perClmProcedureCode_3', 'count_ClaimID_perProviderClmDiagnosisCode_4', 'count_ClaimID_perProviderBeneID', 'mean_Hospital_Days_perBeneID', 'mean_Hospital_Days_perOperatingPhysician', 'mean_InscClaimAmtReimbursed_perBeneID', 'mean_DeductibleAmtPaid_perOtherPhysician', 'ChronicCond_Heartfailure', 'ChronicCond_Depression', 'Race_2', 'count_ClaimID_perProviderOtherPhysician', 'ChronicCond_Cancer', 'mean_Hospital_Days_perClmDiagnosisCode_4', 'mean_Hospital_Days_perClmDiagnosisCode_3', 'mean_Hospital_Days_perClmDiagnosisCode_6', 'ChronicCond_Osteoporasis', 'mean_Hospital_Days_perClmAdmitDiagnosisCode', 'mean_InscClaimAmtReimbursed_perClmDiagnosisCode_4', 'mean_Hospital_Days_perClmProcedureCode_1']
# Final X_train Shape =  (4902, 50)
# Final X_cv Shape =  (1623, 50)

# %% [markdown]
# #### 6.3.4 Store the Train and CV(Test) Data as csv for future use

# %%
X_train_std_df = pd.DataFrame(X_train_std, columns=imp_feat)                   # store Final X_train as dataframe 
X_cv_std_df = pd.DataFrame(X_cv_std, columns=imp_feat)                         # store Final X_cv as dataframe 
x_pf = pd.DataFrame(y_train, columns = ['PotentialFraud'])
X_train_std_df['PotentialFraud'] = list(x_pf['PotentialFraud'])                # store y_train in Final X_train dataframe
x_pf = pd.DataFrame(y_cv, columns = ['PotentialFraud'])
X_cv_std_df['PotentialFraud'] = list(x_pf['PotentialFraud'])                   # store y_cv in Final X_cv dataframe

X_train_std_df.to_csv('Final_train3.csv', index = False)                       # store important features as csv for X_train
X_cv_std_df.to_csv('Final_cv3.csv', index = False)                             # store important features as csv for X_cv

# %% [markdown]
# ## 7. Modelling with Synthetic Minority Oversampling
# ### 7.1 Fitting logistic regression with best hyperparameters

# %%
model1 = LogisticRegression(penalty='l2',
                            C=0.4430621,
                            tol=0.0001,
                            fit_intercept=True,
                            class_weight='balanced',
                            random_state=49,
                            solver='liblinear',  
                            max_iter=200)

model1.fit(X_train_std, y_train)

best_t, model_auc, train_f1_score, cv_f1_score = model_validation(model1, X_train_std, X_cv_std, y_train, y_cv)      # function call
print('Best Threshold = {:.4f}'.format(best_t))
print('Model AUC = {:.4f}'.format(model_auc))
print('Train F1 Score = {:.4f}'.format(train_f1_score))
print('CV F1 Score = {:.4f}'.format(cv_f1_score))
# Out:
# Train AUC = 0.9439211417949797
# CV AUC = 0.9482763247343375
# Best Threshold = 0.3536
# Model AUC = 0.9483
# Train F1 Score = 0.8179
# CV F1 Score = 0.6018

# %% [markdown]
# #### 7.1.1 Finding the most important features using logistic regression with best hyperparameters

# %%
feat_weights = list(model1.coef_[0])
imp_features(imp_feat, feat_weights, False, 'Most Important ')                     # function call
# Out:
#                                              Features   Weights
# 0       mean_InscClaimAmtReimbursed_perOtherPhysician  2.120344
# 1            mean_Hospital_Days_perAttendingPhysician  1.948105
# 2   mean_InscClaimAmtReimbursed_perClmProcedureCode_1  1.891353
# 3                     count_ClaimID_perProviderBeneID  1.720764
# 4            mean_Hospital_Days_perOperatingPhysician  1.045501
# 5            mean_Hospital_Days_perClmDiagnosisCode_2  0.912501
# 6               mean_InscClaimAmtReimbursed_perBeneID  0.906271
# 7         mean_Hospital_Days_perClmAdmitDiagnosisCode  0.850188
# 8   mean_InscClaimAmtReimbursed_perClmProcedureCode_2  0.816651
# 9                            ChronicCond_Heartfailure  0.640451
# 10           mean_Hospital_Days_perClmDiagnosisCode_5  0.614499
# 11    mean_DeductibleAmtPaid_perClmAdmitDiagnosisCode  0.588967
# 12           mean_DeductibleAmtPaid_perOtherPhysician  0.574505
# 13                              RenalDiseaseIndicator  0.559321
# 14        count_ClaimID_perProviderClmDiagnosisCode_4  0.506639

# %% [markdown]
# #### 7.1.2 Finding the least important features using logistic regression with best hyperparameters

# %%
imp_features(imp_feat, feat_weights, True, 'Least Important ')                # function call
# Out:
#                                              Features   Weights
# 0                mean_Hospital_Days_perOtherPhysician -1.397637
# 1   mean_InscClaimAmtReimbursed_perClmDiagnosisCode_3 -1.382005
# 2            mean_Hospital_Days_perClmDiagnosisCode_3 -1.360475
# 3                    mean_DeductibleAmtPaid_perBeneID -1.253006
# 4                                            Gender_0 -1.184100
# 5            mean_Hospital_Days_perClmDiagnosisCode_4 -1.095195
# 6            mean_Hospital_Days_perClmProcedureCode_1 -0.940155
# 7            mean_Hospital_Days_perClmProcedureCode_3 -0.843375
# 8                               ChronicCond_Alzheimer -0.638911
# 9               mean_Claim_Days_perOperatingPhysician -0.596761
# 10       mean_DeductibleAmtPaid_perOperatingPhysician -0.478366
# 11          mean_Hospital_Days_perClmDiagnosisCode_10 -0.439447
# 12       mean_DeductibleAmtPaid_perAttendingPhysician -0.366275
# 13  mean_InscClaimAmtReimbursed_perClmDiagnosisCode_4 -0.362628
# 14                                             Race_2 -0.358555

# %% [markdown]
# #### 7.1.3 Summary of results and its comparison with other models

# %%
data.add_row(['Logistic Regression', '70:30', 'Synthetic Minority Oversampling', 0.9439, 0.9483, 0.8179, 0.6018, 16])

print(data)
# Out:
# +---------------------+----------------+---------------------------------+-----------+--------+----------------+-------------+-----------------+
# |        Model        | Sampling Ratio |   Solution for Imbalanced Data  | Train AUC | CV AUC | Train F1 Score | CV F1 Score | False Negatives |
# +---------------------+----------------+---------------------------------+-----------+--------+----------------+-------------+-----------------+
# | Logistic Regression |     70:30      |     Class Weight = Balanced     |   0.9406  | 0.9532 |     0.5751     |    0.6044   |        16       |
# |    Decision Trees   |     70:30      |     Class Weight = Balanced     |   0.9251  | 0.9281 |     0.5307     |    0.5473   |        16       |
# |  XGBoost Classifier |     70:30      |      Scale Positive Weight      |   0.9839  | 0.9499 |     0.786      |    0.6431   |        34       |
# | Logistic Regression |     80:20      |     Class Weight = Balanced     |   0.9435  | 0.9482 |     0.6103     |    0.5979   |        17       |
# |    Decision Trees   |     80:20      |     Class Weight = Balanced     |   0.9236  | 0.9156 |     0.583      |    0.5843   |        23       |
# |  XGBoost Classifier |     80:20      |      Scale Positive Weight      |   0.9822  | 0.9426 |     0.7954     |    0.5917   |        30       |
# | Logistic Regression |     70:30      | Synthetic Minority Oversampling |   0.9439  | 0.9483 |     0.8179     |    0.6018   |        16       |
# +---------------------+----------------+---------------------------------+-----------+--------+----------------+-------------+-----------------+

# %% [markdown]
# ### 7.2 Fitting decision trees with best hyperparameters

# %%
model3 = DecisionTreeClassifier(criterion='gini',
                                max_depth= 178,
                                min_samples_split=122,
                                min_samples_leaf=280,
                                max_features='auto',
                                random_state=49,
                                class_weight='balanced')

model3.fit(X_train_std, y_train)

best_t, model_auc, train_f1_score, cv_f1_score = model_validation(model3, X_train_std, X_cv_std, y_train, y_cv)       # function call
print('Best Threshold = {:.4f}'.format(best_t))
print('Model AUC = {:.4f}'.format(model_auc))
print('Train F1 Score = {:.4f}'.format(train_f1_score))
print('CV F1 Score = {:.4f}'.format(cv_f1_score))
# Out:
# Train AUC = 0.9376060488467656
# CV AUC = 0.9350669970303052
# Best Threshold = 0.5464
# Model AUC = 0.9351
# Train F1 Score = 0.7731
# CV F1 Score = 0.4955

# %% [markdown]
# #### 7.2.1 Finding the most important features using decision trees with best hyperparameters

# %%
feat_weights = list(model3.feature_importances_)

imp_features(imp_feat, feat_weights, False, 'Most Important ')                     # function call
# Out:
#                                             Features   Weights
# 0           mean_Hospital_Days_perClmProcedureCode_1  0.852791
# 1        mean_Hospital_Days_perClmAdmitDiagnosisCode  0.082532
# 2           mean_Hospital_Days_perAttendingPhysician  0.035221
# 3       mean_DeductibleAmtPaid_perOperatingPhysician  0.019399
# 4                              RenalDiseaseIndicator  0.005931
# 5                        mean_Claim_Days_perProvider  0.001479
# 6              mean_Claim_Days_perOperatingPhysician  0.001168
# 7           mean_Hospital_Days_perClmDiagnosisCode_6  0.001133
# 8           mean_Hospital_Days_perClmDiagnosisCode_5  0.000333
# 9  mean_InscClaimAmtReimbursed_perClmDiagnosisCode_3  0.000013

# %% [markdown]
# #### 7.2.2 Finding the least important features using decision trees with best hyperparameters

# %%
imp_features(imp_feat, feat_weights, True, 'Least Important ')                # function call
# Out:
#                                             Features   Weights
# 0  mean_InscClaimAmtReimbursed_perClmDiagnosisCode_3  0.000013
# 1           mean_Hospital_Days_perClmDiagnosisCode_5  0.000333
# 2           mean_Hospital_Days_perClmDiagnosisCode_6  0.001133
# 3              mean_Claim_Days_perOperatingPhysician  0.001168
# 4                        mean_Claim_Days_perProvider  0.001479
# 5                              RenalDiseaseIndicator  0.005931
# 6       mean_DeductibleAmtPaid_perOperatingPhysician  0.019399
# 7           mean_Hospital_Days_perAttendingPhysician  0.035221
# 8        mean_Hospital_Days_perClmAdmitDiagnosisCode  0.082532
# 9           mean_Hospital_Days_perClmProcedureCode_1  0.852791

# %% [markdown]
# #### 7.2.3 Summary of results and its comparison with other models

# %%
data.add_row(['Decision Trees', '70:30', 'Synthetic Minority Oversampling', 0.9376, 0.9351, 0.7731, 0.4955, 13])

print(data)
# Out:
# +---------------------+----------------+---------------------------------+-----------+--------+----------------+-------------+-----------------+
# |        Model        | Sampling Ratio |   Solution for Imbalanced Data  | Train AUC | CV AUC | Train F1 Score | CV F1 Score | False Negatives |
# +---------------------+----------------+---------------------------------+-----------+--------+----------------+-------------+-----------------+
# | Logistic Regression |     70:30      |     Class Weight = Balanced     |   0.9406  | 0.9532 |     0.5751     |    0.6044   |        16       |
# |    Decision Trees   |     70:30      |     Class Weight = Balanced     |   0.9251  | 0.9281 |     0.5307     |    0.5473   |        16       |
# |  XGBoost Classifier |     70:30      |      Scale Positive Weight      |   0.9839  | 0.9499 |     0.786      |    0.6431   |        34       |
# | Logistic Regression |     80:20      |     Class Weight = Balanced     |   0.9435  | 0.9482 |     0.6103     |    0.5979   |        17       |
# |    Decision Trees   |     80:20      |     Class Weight = Balanced     |   0.9236  | 0.9156 |     0.583      |    0.5843   |        23       |
# |  XGBoost Classifier |     80:20      |      Scale Positive Weight      |   0.9822  | 0.9426 |     0.7954     |    0.5917   |        30       |
# | Logistic Regression |     70:30      | Synthetic Minority Oversampling |   0.9439  | 0.9483 |     0.8179     |    0.6018   |        16       |
# |    Decision Trees   |     70:30      | Synthetic Minority Oversampling |   0.9376  | 0.9351 |     0.7731     |    0.4955   |        13       |
# +---------------------+----------------+---------------------------------+-----------+--------+----------------+-------------+-----------------+

# %% [markdown]
# ### 7.3 Fitting XGB Classifier with best hyperparameters

# %%
model5 = XGBClassifier(n_estimators=263,
                       max_depth= 104,
                       colsample_bytree=0.83333,
                       reg_alpha=16,
                       reg_lambda=33,
                       random_state=49)

model5.fit(X_train_std, y_train)

best_t, model_auc, train_f1_score, cv_f1_score = model_validation(model5, X_train_std, X_cv_std, y_train, y_cv)         # function call
print('Best Threshold = {:.4f}'.format(best_t))
print('Model AUC = {:.4f}'.format(model_auc))
print('Train F1 Score = {:.4f}'.format(train_f1_score))
print('CV F1 Score = {:.4f}'.format(cv_f1_score))
# Out:
# Train AUC = 0.9860893458497658
# CV AUC = 0.9416325271029375
# Best Threshold = 0.4157
# Model AUC = 0.9416
# Train F1 Score = 0.9148
# CV F1 Score = 0.6053

# %% [markdown]
# #### 7.3.1 Finding the most important features using XGB Classifier with best hyperparameters

# %%
feat_weights = list(model5.feature_importances_)

imp_features(imp_feat, feat_weights, False, 'Most Important ')            # function call
# Out:
#                                              Features   Weights
# 0            mean_Hospital_Days_perOperatingPhysician  0.466550
# 1         mean_Hospital_Days_perClmAdmitDiagnosisCode  0.231004
# 2        mean_DeductibleAmtPaid_perAttendingPhysician  0.049830
# 3            mean_Hospital_Days_perClmProcedureCode_1  0.034768
# 4            mean_Hospital_Days_perAttendingPhysician  0.018826
# 5        mean_DeductibleAmtPaid_perOperatingPhysician  0.015773
# 6            mean_Hospital_Days_perClmDiagnosisCode_9  0.011962
# 7                                              Race_5  0.010117
# 8                               RenalDiseaseIndicator  0.008987
# 9   mean_InscClaimAmtReimbursed_perClmProcedureCode_1  0.008846
# 10           mean_Hospital_Days_perClmDiagnosisCode_5  0.008112
# 11                                             Race_3  0.007673
# 12                    count_ClaimID_perProviderBeneID  0.007515
# 13                              ChronicCond_Alzheimer  0.006804
# 14          mean_Hospital_Days_perClmDiagnosisCode_10  0.005984

# %% [markdown]
# #### 7.3.2 Finding the least important features using XGB Classifier with best hyperparameters

# %%
imp_features(imp_feat, feat_weights, True, 'Least Important ')                # function call
# Out:
#                                              Features   Weights
# 0         count_ClaimID_perProviderClmDiagnosisCode_1  0.001427
# 1   mean_InscClaimAmtReimbursed_perClmDiagnosisCode_4  0.001493
# 2                            ChronicCond_Heartfailure  0.001669
# 3             count_ClaimID_perProviderOtherPhysician  0.001683
# 4            mean_Hospital_Days_perClmProcedureCode_2  0.001709
# 5   mean_InscClaimAmtReimbursed_perClmDiagnosisCode_3  0.001805
# 6            mean_Hospital_Days_perClmDiagnosisCode_2  0.001810
# 7                            ChronicCond_Osteoporasis  0.002115
# 8                            OPAnnualReimbursementAmt  0.002262
# 9            mean_Hospital_Days_perClmDiagnosisCode_3  0.002266
# 10  mean_IPAnnualReimbursementAmt_perOperatingPhys...  0.002335
# 11           mean_Hospital_Days_perClmProcedureCode_3  0.002438
# 12                         ChronicCond_ObstrPulmonary  0.002632
# 13              mean_Claim_Days_perOperatingPhysician  0.002663
# 14                                             Race_2  0.002674

# %% [markdown]
# #### 7.3.3 Summary of results and its comparison with other models

# %%
data.add_row(['XGBoost Classifier', '70:30', 'Synthetic Minority Oversampling', 0.9861, 0.9416, 0.9148, 0.6053, 37])

print(data)
# Out:
# +---------------------+----------------+---------------------------------+-----------+--------+----------------+-------------+-----------------+
# |        Model        | Sampling Ratio |   Solution for Imbalanced Data  | Train AUC | CV AUC | Train F1 Score | CV F1 Score | False Negatives |
# +---------------------+----------------+---------------------------------+-----------+--------+----------------+-------------+-----------------+
# | Logistic Regression |     70:30      |     Class Weight = Balanced     |   0.9406  | 0.9532 |     0.5751     |    0.6044   |        16       |
# |    Decision Trees   |     70:30      |     Class Weight = Balanced     |   0.9251  | 0.9281 |     0.5307     |    0.5473   |        16       |
# |  XGBoost Classifier |     70:30      |      Scale Positive Weight      |   0.9839  | 0.9499 |     0.786      |    0.6431   |        34       |
# | Logistic Regression |     80:20      |     Class Weight = Balanced     |   0.9435  | 0.9482 |     0.6103     |    0.5979   |        17       |
# |    Decision Trees   |     80:20      |     Class Weight = Balanced     |   0.9236  | 0.9156 |     0.583      |    0.5843   |        23       |
# |  XGBoost Classifier |     80:20      |      Scale Positive Weight      |   0.9822  | 0.9426 |     0.7954     |    0.5917   |        30       |
# | Logistic Regression |     70:30      | Synthetic Minority Oversampling |   0.9439  | 0.9483 |     0.8179     |    0.6018   |        16       |
# |    Decision Trees   |     70:30      | Synthetic Minority Oversampling |   0.9376  | 0.9351 |     0.7731     |    0.4955   |        13       |
# |  XGBoost Classifier |     70:30      | Synthetic Minority Oversampling |   0.9861  | 0.9416 |     0.9148     |    0.6053   |        37       |
# +---------------------+----------------+---------------------------------+-----------+--------+----------------+-------------+-----------------+

# %% [markdown]
# ## 8. Loading Data
#
# ### 8.1 Splitting and scaling data into Train and Cross Validation(or Test)
#
# #### 8.1.1 Stratified Sampling(80:20)

# %%
X_train_std, X_cv_std, y_train, y_cv, X_train_df, X_cv_df = train_cv_split_scaling(X, y, 0.20)        # function call
# Out:
# X_train Shape =  (4328, 285)
# X_cv Shape =  (1082, 285)
# Y_train Shape =  (4328,)
# Y_cv Shape =  (1082,)

# %% [markdown]
# ### 8.2 SMOTE Sampling(80:20) for Imbalanced Data

# %%
# Code Reference: https://machinelearningmastery.com/smote-oversampling-for-imbalanced-classification/

oversample = SMOTE(sampling_strategy=0.25)
X_train_sample, y_train = oversample.fit_resample(X_train_std, y_train)
print(X_train_sample.shape, y_train.shape)
fraud_per(y_train)
# Out:
# (4903, 285) (4903,)
# Fraud Percentage = 19.99%
# Non-Fraud Percentage = 80.01%

# %% [markdown]
# ### 8.3 Perform Dimensionality Reduction Techniques
#
# #### 8.3.1 Plot TSNE for Train Data (285 dimensions reduced to 2 dimension)

# %%
plot_TSNE(X_train_sample, y_train)                                       # function call

# %% [markdown]
# #### 8.3.2 Perform PCA for Feature Reduction

# %%
feat_reduct_PCA(X_train_sample, X_cv_std, y_cv)                            # function call
# Out:
# AUROC scores for different values of features:
#  [0.9035259578813395, 0.9129551755437489, 0.9092598402667813, 0.9087779150819137, 0.9086869860344429, 0.9088983562968334, 0.9091996196593213, 0.9091923310295836, 0.9090419583351832, 0.9091950195596731, 0.9091439991515099, 0.908889156097537, 0.9089957970135117, 0.909250899054328, 0.908996056000355, 0.9091415696082639, 0.9091415696082639, 0.909243351437747, 0.9091923310295836, 0.909296801389156, 0.9092946308327537, 0.9092409218945011, 0.9092460399678363, 0.9091485992511581, 0.9091464286947556, 0.9092457809809928]

# %% [markdown]
# #### 8.3.3 Replace Train and CV(Test) Data with the best features

# %%
X_train_df = pd.DataFrame(X_train_sample, columns=X.columns)
X_cv_df = pd.DataFrame(X_cv_std, columns=X.columns)
print(X_train_df.shape, X_cv_df.shape)

imp_feat, X_train_std, X_cv_std = feat_after_reduction(40, X_train_sample, X, X_train_df, X_cv_df)               # function call
# Out:
# (4903, 285) (1082, 285)
# Explained Variance using PCA with randomized svd_solver:
#  [8.88635208e-01 7.98509970e-02 2.17511004e-02 4.05528045e-03
#  1.31723964e-03 6.84742778e-04 6.11071442e-04 4.19205927e-04
#  3.78314110e-04 2.81241095e-04 2.53976511e-04 2.27061481e-04
#  1.50986376e-04 1.21424428e-04 1.15480132e-04 1.01160129e-04
#  9.50475846e-05 7.57127556e-05 6.58618154e-05 5.82135397e-05
#  4.93983453e-05 4.75098350e-05 4.20121178e-05 3.94329747e-05
#  3.47389855e-05 3.27735036e-05 3.08747117e-05 2.95726591e-05
#  2.51926811e-05 2.40680092e-05 2.28911827e-05 2.21205271e-05
#  2.12815117e-05 1.98097064e-05 1.82563558e-05 1.76108067e-05
#  1.67957984e-05 1.55715237e-05 1.44830944e-05 1.29137041e-05]
# 100%|██████████| 40/40 [00:00<00:00, 16977.55it/s]
# Unique Feature Names with best Explained Variance Ratio:
#  ['mean_Hospital_Days_perClmDiagnosisCode_5', 'Gender_1', 'mean_InscClaimAmtReimbursed_perOperatingPhysician', 'ChronicCond_rheumatoidarthritis', 'mean_OPAnnualReimbursementAmt_perProvider', 'Gender_0', 'Race_3', 'mean_InscClaimAmtReimbursed_perClmDiagnosisCode_3', 'mean_DeductibleAmtPaid_perBeneID', 'mean_Hospital_Days_perOtherPhysician', 'ChronicCond_ObstrPulmonary', 'OPAnnualReimbursementAmt', 'mean_Hospital_Days_perAttendingPhysician', 'mean_Hospital_Days_perClmDiagnosisCode_2', 'mean_Hospital_Days_perClmDiagnosisCode_10', 'ChronicCond_Alzheimer', 'Claim_Days', 'mean_Claim_Days_perOperatingPhysician', 'mean_Hospital_Days_perClmDiagnosisCode_9', 'RenalDiseaseIndicator', 'count_ClaimID_perProviderClmDiagnosisCode_2', 'mean_DeductibleAmtPaid_perOperatingPhysician', 'mean_Hospital_Days_perClmDiagnosisCode_7', 'Difference', 'Race_1', 'count_ClaimID_perProviderAttendingPhysician', 'count_ClaimID_perProviderClmDiagnosisCode_4', 'count_ClaimID_perProviderBeneID', 'mean_Hospital_Days_perOperatingPhysician', 'mean_DeductibleAmtPaid_perOtherPhysician', 'ChronicCond_Depression', 'Race_2', 'mean_Hospital_Days_perClmDiagnosisCode_8', 'mean_Hospital_Days_perClmDiagnosisCode_3', 'mean_Hospital_Days_perClmDiagnosisCode_4', 'mean_InscClaimAmtReimbursed_perClmDiagnosisCode_9', 'mean_Hospital_Days_perClmDiagnosisCode_6', 'ChronicCond_Osteoporasis', 'mean_Hospital_Days_perClmAdmitDiagnosisCode', 'mean_InscClaimAmtReimbursed_perClmDiagnosisCode_4']
# Final X_train Shape =  (4903, 40)
# Final X_cv Shape =  (1082, 40)

# %% [markdown]
# #### 8.3.4 Store the Train and CV(Test) Data as csv for future use

# %%
X_train_std_df = pd.DataFrame(X_train_std, columns=imp_feat)                   # store Final X_train as dataframe 
X_cv_std_df = pd.DataFrame(X_cv_std, columns=imp_feat)                         # store Final X_cv as dataframe 
x_pf = pd.DataFrame(y_train, columns = ['PotentialFraud'])
X_train_std_df['PotentialFraud'] = list(x_pf['PotentialFraud'])                # store y_train in Final X_train dataframe
x_pf = pd.DataFrame(y_cv, columns = ['PotentialFraud'])
X_cv_std_df['PotentialFraud'] = list(x_pf['PotentialFraud'])                   # store y_cv in Final X_cv dataframe

X_train_std_df.to_csv('Final_train4.csv', index = False)                       # store important features as csv for X_train
X_cv_std_df.to_csv('Final_cv4.csv', index = False)                             # store important features as csv for X_cv

# %% [markdown]
# ## 9. Modelling with Synthetic Minority Oversampling
# ### 9.1 Fitting logistic regression with best hyperparameters

# %%
model1 = LogisticRegression(penalty='l2',
                            C=0.443062,
                            tol=0.0001,
                            fit_intercept=True,
                            class_weight='balanced',
                            random_state=49,
                            solver='liblinear',  
                            max_iter=200)

model1.fit(X_train_std, y_train)

best_t, model_auc, train_f1_score, cv_f1_score = model_validation(model1, X_train_std, X_cv_std, y_train, y_cv)      # function call
print('Best Threshold = {:.4f}'.format(best_t))
print('Model AUC = {:.4f}'.format(model_auc))
print('Train F1 Score = {:.4f}'.format(train_f1_score))
print('CV F1 Score = {:.4f}'.format(cv_f1_score))
# Out:
# Train AUC = 0.9465577156174729
# CV AUC = 0.9392416305850768
# Best Threshold = 0.3257
# Model AUC = 0.9392
# Train F1 Score = 0.7352
# CV F1 Score = 0.5662

# %% [markdown]
# #### 9.1.1 Finding the most important features using logistic regression with best hyperparameters

# %%
feat_weights = list(model1.coef_[0])
imp_features(imp_feat, feat_weights, False, 'Most Important ')           # function call
# Out:
#                                              Features   Weights
# 0   mean_InscClaimAmtReimbursed_perOperatingPhysician  3.164862
# 1                     count_ClaimID_perProviderBeneID  1.735183
# 2            mean_DeductibleAmtPaid_perOtherPhysician  1.208248
# 3            mean_Hospital_Days_perAttendingPhysician  1.144283
# 4            mean_Hospital_Days_perClmDiagnosisCode_5  1.114239
# 5            mean_Hospital_Days_perOperatingPhysician  1.069847
# 6         mean_Hospital_Days_perClmAdmitDiagnosisCode  0.873365
# 7                               RenalDiseaseIndicator  0.857834
# 8         count_ClaimID_perProviderClmDiagnosisCode_4  0.784408
# 9         count_ClaimID_perProviderClmDiagnosisCode_2  0.755982
# 10           mean_Hospital_Days_perClmDiagnosisCode_2  0.582798
# 11                         ChronicCond_ObstrPulmonary  0.557461
# 12           mean_Hospital_Days_perClmDiagnosisCode_9  0.544544
# 13                                             Race_3  0.458958
# 14        count_ClaimID_perProviderAttendingPhysician  0.447849

# %% [markdown]
# #### 9.1.2 Finding the least important features using logistic regression with best hyperparameters

# %%
imp_features(imp_feat, feat_weights, True, 'Least Important ')          # function call
# Out:
#                                              Features   Weights
# 0        mean_DeductibleAmtPaid_perOperatingPhysician -1.372311
# 1            mean_Hospital_Days_perClmDiagnosisCode_3 -1.117806
# 2                mean_Hospital_Days_perOtherPhysician -1.018955
# 3   mean_InscClaimAmtReimbursed_perClmDiagnosisCode_3 -1.009754
# 4   mean_InscClaimAmtReimbursed_perClmDiagnosisCode_9 -0.831633
# 5                               ChronicCond_Alzheimer -0.739245
# 6                     ChronicCond_rheumatoidarthritis -0.715423
# 7   mean_InscClaimAmtReimbursed_perClmDiagnosisCode_4 -0.697941
# 8            mean_Hospital_Days_perClmDiagnosisCode_4 -0.610037
# 9                                              Race_2 -0.471476
# 10                                           Gender_0 -0.403437
# 11           mean_Hospital_Days_perClmDiagnosisCode_6 -0.377882
# 12                   mean_DeductibleAmtPaid_perBeneID -0.364625
# 13                                             Race_1 -0.339349
# 14              mean_Claim_Days_perOperatingPhysician -0.157682

# %% [markdown]
# #### 9.1.3 Summary of results and its comparison with other models

# %%
data.add_row(['Logistic Regression', '80:20', 'Synthetic Minority Oversampling', 0.9466, 0.9392, 0.7352, 0.5662, 9])

print(data)
# Out:
# +---------------------+----------------+---------------------------------+-----------+--------+----------------+-------------+-----------------+
# |        Model        | Sampling Ratio |   Solution for Imbalanced Data  | Train AUC | CV AUC | Train F1 Score | CV F1 Score | False Negatives |
# +---------------------+----------------+---------------------------------+-----------+--------+----------------+-------------+-----------------+
# | Logistic Regression |     70:30      |     Class Weight = Balanced     |   0.9406  | 0.9532 |     0.5751     |    0.6044   |        16       |
# |    Decision Trees   |     70:30      |     Class Weight = Balanced     |   0.9251  | 0.9281 |     0.5307     |    0.5473   |        16       |
# |  XGBoost Classifier |     70:30      |      Scale Positive Weight      |   0.9839  | 0.9499 |     0.786      |    0.6431   |        34       |
# | Logistic Regression |     80:20      |     Class Weight = Balanced     |   0.9435  | 0.9482 |     0.6103     |    0.5979   |        17       |
# |    Decision Trees   |     80:20      |     Class Weight = Balanced     |   0.9236  | 0.9156 |     0.583      |    0.5843   |        23       |
# |  XGBoost Classifier |     80:20      |      Scale Positive Weight      |   0.9822  | 0.9426 |     0.7954     |    0.5917   |        30       |
# | Logistic Regression |     70:30      | Synthetic Minority Oversampling |   0.9439  | 0.9483 |     0.8179     |    0.6018   |        16       |
# |    Decision Trees   |     70:30      | Synthetic Minority Oversampling |   0.9376  | 0.9351 |     0.7731     |    0.4955   |        13       |
# |  XGBoost Classifier |     70:30      | Synthetic Minority Oversampling |   0.9861  | 0.9416 |     0.9148     |    0.6053   |        37       |
# | Logistic Regression |     80:20      | Synthetic Minority Oversampling |   0.9466  | 0.9392 |     0.7352     |    0.5662   |        9        |
# +---------------------+----------------+---------------------------------+-----------+--------+----------------+-------------+-----------------+

# %% [markdown]
# ### 9.2 Fitting decision trees with best hyperparameters

# %%
model3 = DecisionTreeClassifier(criterion='gini',
                                max_depth= 178,
                                min_samples_split=122,
                                min_samples_leaf=280,
                                max_features='auto',
                                random_state=49,
                                class_weight='balanced')

model3.fit(X_train_std, y_train)

best_t, model_auc, train_f1_score, cv_f1_score = model_validation(model3, X_train_std, X_cv_std, y_train, y_cv)       # function call
print('Best Threshold = {:.4f}'.format(best_t))
print('Model AUC = {:.4f}'.format(model_auc))
print('Train F1 Score = {:.4f}'.format(train_f1_score))
print('CV F1 Score = {:.4f}'.format(cv_f1_score))
# Out:
# Train AUC = 0.931778574289772
# CV AUC = 0.9343769239309252
# Best Threshold = 0.7393
# Model AUC = 0.9344
# Train F1 Score = 0.7251
# CV F1 Score = 0.5531

# %% [markdown]
# #### 9.2.1 Finding the most important features using decision trees with best hyperparameters

# %%
feat_weights = list(model3.feature_importances_)

imp_features(imp_feat, feat_weights, False, 'Most Important ')            # function call
# Out:
#                                             Features       Weights
# 0  mean_InscClaimAmtReimbursed_perOperatingPhysician  8.316108e-01
# 1           mean_Hospital_Days_perOperatingPhysician  1.236298e-01
# 2           mean_Hospital_Days_perClmDiagnosisCode_5  3.500704e-02
# 3           mean_Hospital_Days_perClmDiagnosisCode_7  5.699081e-03
# 4                                           Gender_1  3.099925e-03
# 5                              RenalDiseaseIndicator  8.290212e-04
# 6           mean_Hospital_Days_perClmDiagnosisCode_3  9.975712e-05
# 7           mean_Hospital_Days_perClmDiagnosisCode_8  2.462546e-05
# 8           mean_Hospital_Days_perClmDiagnosisCode_6  1.571471e-16

# %% [markdown]
# #### 9.2.2 Finding the least important features using decision trees with best hyperparameters

# %%
imp_features(imp_feat, feat_weights, True, 'Least Important ')          # function call
# Out:
#                                             Features       Weights
# 0           mean_Hospital_Days_perClmDiagnosisCode_6  1.571471e-16
# 1           mean_Hospital_Days_perClmDiagnosisCode_8  2.462546e-05
# 2           mean_Hospital_Days_perClmDiagnosisCode_3  9.975712e-05
# 3                              RenalDiseaseIndicator  8.290212e-04
# 4                                           Gender_1  3.099925e-03
# 5           mean_Hospital_Days_perClmDiagnosisCode_7  5.699081e-03
# 6           mean_Hospital_Days_perClmDiagnosisCode_5  3.500704e-02
# 7           mean_Hospital_Days_perOperatingPhysician  1.236298e-01
# 8  mean_InscClaimAmtReimbursed_perOperatingPhysician  8.316108e-01

# %% [markdown]
# #### 9.2.3 Summary of results and its comparison with other models

# %%
data.add_row(['Decision Trees', '80:20', 'Synthetic Minority Oversampling', 0.9318, 0.9344, 0.7251, 0.5531, 15])

print(data)
# Out:
# +---------------------+----------------+---------------------------------+-----------+--------+----------------+-------------+-----------------+
# |        Model        | Sampling Ratio |   Solution for Imbalanced Data  | Train AUC | CV AUC | Train F1 Score | CV F1 Score | False Negatives |
# +---------------------+----------------+---------------------------------+-----------+--------+----------------+-------------+-----------------+
# | Logistic Regression |     70:30      |     Class Weight = Balanced     |   0.9406  | 0.9532 |     0.5751     |    0.6044   |        16       |
# |    Decision Trees   |     70:30      |     Class Weight = Balanced     |   0.9251  | 0.9281 |     0.5307     |    0.5473   |        16       |
# |  XGBoost Classifier |     70:30      |      Scale Positive Weight      |   0.9839  | 0.9499 |     0.786      |    0.6431   |        34       |
# | Logistic Regression |     80:20      |     Class Weight = Balanced     |   0.9435  | 0.9482 |     0.6103     |    0.5979   |        17       |
# |    Decision Trees   |     80:20      |     Class Weight = Balanced     |   0.9236  | 0.9156 |     0.583      |    0.5843   |        23       |
# |  XGBoost Classifier |     80:20      |      Scale Positive Weight      |   0.9822  | 0.9426 |     0.7954     |    0.5917   |        30       |
# | Logistic Regression |     70:30      | Synthetic Minority Oversampling |   0.9439  | 0.9483 |     0.8179     |    0.6018   |        16       |
# |    Decision Trees   |     70:30      | Synthetic Minority Oversampling |   0.9376  | 0.9351 |     0.7731     |    0.4955   |        13       |
# |  XGBoost Classifier |     70:30      | Synthetic Minority Oversampling |   0.9861  | 0.9416 |     0.9148     |    0.6053   |        37       |
# | Logistic Regression |     80:20      | Synthetic Minority Oversampling |   0.9466  | 0.9392 |     0.7352     |    0.5662   |        9        |
# |    Decision Trees   |     80:20      | Synthetic Minority Oversampling |   0.9318  | 0.9344 |     0.7251     |    0.5531   |        15       |
# +---------------------+----------------+---------------------------------+-----------+--------+----------------+-------------+-----------------+

# %% [markdown]
# ### 9.3 Fitting XGB Classifier with best hyperparameters

# %%
model5 = XGBClassifier(n_estimators= 263,
                       max_depth= 104,
                       colsample_bytree=0.83333,
                       reg_alpha=16,
                       reg_lambda=33,
                       random_state=49)

model5.fit(X_train_std, y_train)

best_t, model_auc, train_f1_score, cv_f1_score = model_validation(model5, X_train_std, X_cv_std, y_train, y_cv)      # function call
print('Best Threshold = {:.4f}'.format(best_t))
print('Model AUC = {:.4f}'.format(model_auc))
print('Train F1 Score = {:.4f}'.format(train_f1_score))
print('CV F1 Score = {:.4f}'.format(cv_f1_score))
# Out:
# Train AUC = 0.9766730220000313
# CV AUC = 0.9417042621693361
# Best Threshold = 0.2966
# Model AUC = 0.9417
# Train F1 Score = 0.8333
# CV F1 Score = 0.6029

# %% [markdown]
# #### 9.3.1 Finding the most important features using XGB Classifier with best hyperparameters

# %%
feat_weights = list(model5.feature_importances_)

imp_features(imp_feat, feat_weights, False, 'Most Important ')           # function call
# Out:
#                                              Features   Weights
# 0            mean_Hospital_Days_perOperatingPhysician  0.554532
# 1   mean_InscClaimAmtReimbursed_perOperatingPhysician  0.088597
# 2            mean_Hospital_Days_perAttendingPhysician  0.067148
# 3        mean_DeductibleAmtPaid_perOperatingPhysician  0.037548
# 4            mean_Hospital_Days_perClmDiagnosisCode_5  0.026943
# 5            mean_Hospital_Days_perClmDiagnosisCode_9  0.026346
# 6                     count_ClaimID_perProviderBeneID  0.022152
# 7         mean_Hospital_Days_perClmAdmitDiagnosisCode  0.022128
# 8         count_ClaimID_perProviderClmDiagnosisCode_4  0.010596
# 9         count_ClaimID_perProviderClmDiagnosisCode_2  0.009450
# 10                         ChronicCond_ObstrPulmonary  0.008835
# 11                                         Difference  0.006761
# 12           mean_Hospital_Days_perClmDiagnosisCode_2  0.006586
# 13  mean_InscClaimAmtReimbursed_perClmDiagnosisCode_4  0.005868
# 14                                             Race_2  0.005854

# %% [markdown]
# #### 9.3.2 Finding the least important features using XGB Classifier with best hyperparameters

# %%
imp_features(imp_feat, feat_weights, True, 'Least Important ')          # function call
# Out:
#                                              Features   Weights
# 0                     ChronicCond_rheumatoidarthritis  0.002331
# 1            mean_DeductibleAmtPaid_perOtherPhysician  0.002502
# 2            mean_Hospital_Days_perClmDiagnosisCode_7  0.002675
# 3   mean_InscClaimAmtReimbursed_perClmDiagnosisCode_3  0.002723
# 4                                              Race_1  0.002800
# 5               mean_Claim_Days_perOperatingPhysician  0.003034
# 6           mean_Hospital_Days_perClmDiagnosisCode_10  0.003386
# 7                            ChronicCond_Osteoporasis  0.003457
# 8                                          Claim_Days  0.003479
# 9                    mean_DeductibleAmtPaid_perBeneID  0.003540
# 10        count_ClaimID_perProviderAttendingPhysician  0.003561
# 11                             ChronicCond_Depression  0.003637
# 12          mean_OPAnnualReimbursementAmt_perProvider  0.003726
# 13                                           Gender_1  0.004331
# 14           mean_Hospital_Days_perClmDiagnosisCode_6  0.004359

# %% [markdown]
# #### 9.3.3 Summary of results and its comparison with other models

# %%
data.add_row(['XGBoost Classifier', '80:20', 'Synthetic Minority Oversampling', 0.9767, 0.9417, 0.8333, 0.6029, 19])

print(data)
# Out:
# +---------------------+----------------+---------------------------------+-----------+--------+----------------+-------------+-----------------+
# |        Model        | Sampling Ratio |   Solution for Imbalanced Data  | Train AUC | CV AUC | Train F1 Score | CV F1 Score | False Negatives |
# +---------------------+----------------+---------------------------------+-----------+--------+----------------+-------------+-----------------+
# | Logistic Regression |     70:30      |     Class Weight = Balanced     |   0.9406  | 0.9532 |     0.5751     |    0.6044   |        16       |
# |    Decision Trees   |     70:30      |     Class Weight = Balanced     |   0.9251  | 0.9281 |     0.5307     |    0.5473   |        16       |
# |  XGBoost Classifier |     70:30      |      Scale Positive Weight      |   0.9839  | 0.9499 |     0.786      |    0.6431   |        34       |
# | Logistic Regression |     80:20      |     Class Weight = Balanced     |   0.9435  | 0.9482 |     0.6103     |    0.5979   |        17       |
# |    Decision Trees   |     80:20      |     Class Weight = Balanced     |   0.9236  | 0.9156 |     0.583      |    0.5843   |        23       |
# |  XGBoost Classifier |     80:20      |      Scale Positive Weight      |   0.9822  | 0.9426 |     0.7954     |    0.5917   |        30       |
# | Logistic Regression |     70:30      | Synthetic Minority Oversampling |   0.9439  | 0.9483 |     0.8179     |    0.6018   |        16       |
# |    Decision Trees   |     70:30      | Synthetic Minority Oversampling |   0.9376  | 0.9351 |     0.7731     |    0.4955   |        13       |
# |  XGBoost Classifier |     70:30      | Synthetic Minority Oversampling |   0.9861  | 0.9416 |     0.9148     |    0.6053   |        37       |
# | Logistic Regression |     80:20      | Synthetic Minority Oversampling |   0.9466  | 0.9392 |     0.7352     |    0.5662   |        9        |
# |    Decision Trees   |     80:20      | Synthetic Minority Oversampling |   0.9318  | 0.9344 |     0.7251     |    0.5531   |        15       |
# |  XGBoost Classifier |     80:20      | Synthetic Minority Oversampling |   0.9767  | 0.9417 |     0.8333     |    0.6029   |        19       |
# +---------------------+----------------+---------------------------------+-----------+--------+----------------+-------------+-----------------+

# %% [markdown]
# ## 10. Conclusion from Model Training
#
# 1. The following aggregated features are <b>useful</b> in achieving good model performance:
# <ol type = 'a'>
# <li>Attending Physician</li>
# <li>Operating Physician</li>
# <li>Other Physician</li>
# <li>Hospitalization Days</li>
# <li>Provider</li>
# <li>Claim Days</li>
# <li>Beneficiary ID</li>
# <li>Renal Disease Indicator</li>
# <li>Diagnostic Codes(2,4,5,8,9)</li>
# <li>Race_3</li>
# <li>Insurance Claim Reimbursement Amount</li>
# </ol>
# 2. The above mentioned Aggregated features(that capture the interactions b/w the different parties involved in the <b>Claim</b> process have certainly helped in achieving the <b>good performance scores</b>.
# 3. <b>Synthetic Minority Oversampling</b> <u>doesn't provide gain</u> in the model's performance. Hence, this is not of much use.
# 4. As of now, <b>Logistic Regression</b> with <u>Class Weight = Balanced and 70:30 Train CV Split</u> is working <b>best</b> from the modelling carried out so far.
